# %%
import PriceRatioExperiment as PRE

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import random
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 import PriceRatioExperiment as PRE
#       3 import numpy as np
#       4 import seaborn as sns
#
# ModuleNotFoundError: No module named 'PriceRatioExperiment'

# %%
prod_values = np.logspace(-1, 1, 11)
labor_coeffs = 1.0/prod_values

# %%
labor_coeffs
# Out:
# array([10.        ,  6.30957344,  3.98107171,  2.51188643,  1.58489319,
#         1.        ,  0.63095734,  0.39810717,  0.25118864,  0.15848932,
#         0.1       ])

# %%
for l1 in labor_coeffs:
    for l2 in labor_coeffs:
    
        c1 = np.random.uniform(0, 1.0/l1)
        c2 = 1.0/l2*(1.0 - l1*c1)

# %%
PRE.PriceRatioExperiment(100, l1, l2, c1, c2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 PRE.PriceRatioExperiment(100, l1, l2, c1, c2)
#
# NameError: name 'PRE' is not defined
