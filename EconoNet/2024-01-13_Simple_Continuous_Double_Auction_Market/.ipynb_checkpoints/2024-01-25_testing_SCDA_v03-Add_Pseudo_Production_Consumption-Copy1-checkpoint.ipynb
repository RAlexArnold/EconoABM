# %%
import Agents
import MarketsV03 as Markets

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import random

# %%
epsilon = 0.005
theta = 0.1

NA = 50
NB = 50
N = NA+NB

initialize_money = 'set'
M = 100.

n = 2

QA1 = 0.
QA2 = 0.

qA1 = 5.
qA2 = 0.

cA1 = 0.
cA2 = 5.

QB1 = 0.
QB2 = 0.

qB1 = 0.
qB2 = 5.

cB1 = 5.
cB2 = 0.

QA_0 = np.array([QA1, QA2])
QB_0 = np.array([QB1, QB2])

QA = np.copy(QA_0)
QB = np.copy(QB_0)

qA = np.array([qA1, qA2])
qB = np.array([qB1, qB2])

cA = np.array([cA1, cA2])
cB = np.array([cB1, cB2])

DA = cA.copy()
DB = cB.copy()

initialize_prices = 'set'

p1buy_A_0    = 0. 
p1sell_A_0   = 1.

p2buy_A_0    = 0.
p2sell_A_0   = 0. 

p1buy_B_0    = 1.
p1sell_B_0   = 0. 

p2buy_B_0    = 0.
p2sell_B_0   = 0.

# %%
def add_price_data(df, t):
    
    p_buy, p_sell = df
    
    for v, agent in enumerate(agent_list):
        p_buy[t][v] = agent.p_buy
        p_sell[t][v] = agent.p_sell
        
def add_quant_data(df, t):

    for v,agent in enumerate(agent_list):

        df[t][v] = agent.Q
    
def add_deficit_data(df, t):

    for v,agent in enumerate(agent_list):

        df[t][v] = agent.D
    
def add_money_data(df, t):
    
    for v,agent in enumerate(agent_list):

        df[t][v] = agent.M

# %%
def reset():
    
    for agent in agentA_list:
        
        if initialize_prices=='random':
            
            agent.p_buy  = np.random.uniform(agent.M, size=n)
            agent.p_sell = np.random.uniform(agent.M, size=n)
            
        else:
            agent.p_buy  = [p1buy_A_0, p2buy_A_0]
            agent.p_sell = [p1sell_A_0, p2sell_A_0]
        
    for agent in agentB_list:
        
        if initialize_prices=='random':
            agent.p_buy  = np.random.uniform(agent.M, size=n)
            agent.p_sell = np.random.uniform(agent.M, size=n)
        
        else:
            agent.p_buy  = [p1buy_B_0, p2buy_B_0]
            agent.p_sell = [p1sell_B_0, p2sell_B_0]
            
def market_supply_demand(i):
    supply0 = 0
    demand0 = 0
    for agent in agent_list:

        quants = scda.determine_market_quantity(agent)

        if quants[i] > 0:
            supply0 += quants[i]
        elif quants[i] < 0:
            demand0 += -quants[i]
            
    return supply0, demand0

# %%
agentA_list = [Agents.Agent(QA.copy(), DA.copy(), M, n_actions=1, input_dims=[1]) for v in range(NA)]
agentB_list = [Agents.Agent(QB.copy(), DB.copy(), M, n_actions=1, input_dims=[1]) for v in range(NB)]

agent_list = agentA_list + agentB_list

# %%
M_dict = {}

for agent in agent_list:
    
    M_dict[agent] = np.random.uniform(M)

# %%
M_total = 0
for agent in agent_list:
    M_total += agent.M
    
M_total
# Out:
# 10000.0

# %%
# Initialize agent asking and bidding prices

# %%
max_tries = 100 #3 #1*N #1

# %%
scda = Markets.SCDA(n, theta=theta, gamma=1.0, epsilon=0.01, max_tries=max_tries, M_min=0.01, peval='log_mean')
ExchangeDict = {agent : 2 for agent in agent_list}

# %%
def randomize_prices():

    for agent in agent_list:

        if random.random() < epsilon:
            agent.p_buy = np.random.uniform(0, agent.M, n)

        if random.random() < epsilon:
            agent.p_sell = np.random.uniform(0, agent.M, n)

# %%
T = 1000

reset()

# Setup data
p_buy, p_sell = np.zeros((T, N, n)), np.zeros((T, N, n))
p_df = (p_buy, p_sell)

Q_df = np.zeros((T, N, n))
D_df = np.zeros((T, N, n))
M_df = np.zeros((T, N))

# Setup data
ME_df = np.zeros((T-1,n))
QE_df = np.zeros((T-1,n))
ntries_df = []
    
supply_df = []
demand_df = []

add_price_data(p_df, 0)
add_quant_data(Q_df, 0)
add_deficit_data(D_df, 0)
add_money_data(M_df, 0)

Q__ = QA.copy()

# Run market
for t in range(T-1):
    
    if t % 100 == 0:
        print(t)

    supply0_t, demand0_t = market_supply_demand(0)
    supply1_t, demand1_t = market_supply_demand(1)
    
    supply_t = [supply0_t, supply1_t]
    demand_t = [demand0_t, demand1_t]

    # Market action occurs at half-time interval
    ME, QE, ntries = scda.run_exchange(ExchangeDict)

    # Reset quantities
    for agentA in agentA_list:

        agentA.D = agentA.D + cA
        agentA.Q = np.maximum(0, agentA.Q + qA - np.minimum(agentA.Q, agentA.D))
        

    for agentB in agentB_list:

        agentB.D = agentB.D + cB
        agentB.Q = np.maximum(0, agentB.Q + qB - np.minimum(agentB.Q, agentB.D))
        
    add_price_data(p_df, t+1)
    add_quant_data(Q_df, t+1)
    add_deficit_data(D_df, t)
    add_money_data(M_df, t)

    # Market action occurs at half-time interval
    ME_df[t] = ME
    QE_df[t] = QE
    ntries_df.append(ntries)

    supply_df.append(supply_t)
    demand_df.append(demand_t)
    
    randomize_prices()

p = ME_df/QE_df

supply_df = np.array(supply_df)
demand_df = np.array(demand_df)
# Out:
# 0
# 100
# 200
# C:\Users\Alex\Documents\Research\EconoABM\EconoNet\2024-01-13_Simple_Continuous_Double_Auction_Market\MarketsV03.py:194: RuntimeWarning: overflow encountered in divide
#   buyer_agents = np.random.choice(self.exchanging_agent_list[self.buyers_mask],  p=softmax_bids, size=N_transacting_agents, replace=False)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 41
#      38 demand_t = [demand0_t, demand1_t]
#      40 # Market action occurs at half-time interval
# ---> 41 ME, QE, ntries = scda.run_exchange(ExchangeDict)
#      43 # Reset quantities
#      44 for agentA in agentA_list:
#
# File ~\Documents\Research\EconoABM\EconoNet\2024-01-13_Simple_Continuous_Double_Auction_Market\MarketsV03.py:294, in SCDA.run_exchange(self, ExchangeDict)
#     289 self.uncleared_commodities = list(range(self.Nproducts))
#     292 while (len(self.uncleared_commodities) > 0) and (self.n_tries < self.max_tries):
#     293     # Attempt trial to let all buyers/sellers attempt transacting
# --> 294     self.attempt_trial()
#     296 # Save the new bid and asking prices to the agent states
#     297 self.record_updated_prices()
#
# File ~\Documents\Research\EconoABM\EconoNet\2024-01-13_Simple_Continuous_Double_Auction_Market\MarketsV03.py:194, in SCDA.attempt_trial(self)
#     191 softmax_asks = scipy.special.softmax(-asking_prices_i)
#     193 #buyer_agents  = select_agents_softmax(exchanging_agent_list[buyers_mask], softmax_bids, N_transacting_agents) #np.random.choice(exchanging_agent_list[buyers_mask],  p=softmax_bids)
# --> 194 buyer_agents = np.random.choice(self.exchanging_agent_list[self.buyers_mask],  p=softmax_bids, size=N_transacting_agents, replace=False)
#     195 buyer_indices = [self.agent_mapping[buyer_agent] for buyer_agent in buyer_agents] #agent_mapping[buyer_agents] # will this work?
#     197 #seller_agents = select_agents_softmax(exchanging_agent_list[sellers_mask], softmax_asks, N_transacting_agents)
#
# File mtrand.pyx:1007, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Fewer non-zero entries in p than size

# %%
sum(scda.buyers_mask)
len(scda.exchanging_agent_list[scda.buyers_mask])
# Out:
# 50

# %%
scda.buyers_mask.sum(), scda.sellers_mask.sum()
# Out:
# (50, 13)

# %%
self = scda

i = 1
agent_data_i = scda.agent_data[:,:,i]

self.buyers_mask = (agent_data_i[:, 2] < 0) & (self.agent_Mdata > self.M_min)
buyers_data_i = agent_data_i[self.buyers_mask]

# Creat mask for sellers and select their data
self.sellers_mask = agent_data_i[:, 2] > 0
sellers_data_i = agent_data_i[self.sellers_mask]

N_buyers  = self.buyers_mask.sum()
N_sellers = self.sellers_mask.sum()

N_transacting_agents = min(N_buyers, N_sellers)

N_buyers, N_sellers
# Out:
# (50, 13)

# %%
bidding_prices_i = buyers_data_i[:,0]
buyers_data_i.shape
# Out:
# (50, 3)

# %%
asking_prices_i  = sellers_data_i[:,1]
asking_prices_i.shape
# Out:
# (13,)

# %%
bidding_prices_i
# Out:
# array([1.30769499e+00, 4.38483418e+00, 0.00000000e+00, 0.00000000e+00,
#        5.81707293e+01, 1.30602028e+00, 0.00000000e+00, 0.00000000e+00,
#        7.56009666e+01, 1.47864210e+00, 0.00000000e+00, 2.93429129e+01,
#        0.00000000e+00, 0.00000000e+00, 2.17389260e+01, 8.42003920e+00,
#        0.00000000e+00, 8.53199253e+01, 1.63182156e+00, 0.00000000e+00,
#        0.00000000e+00, 1.55282895e+02, 4.43404900e+00, 0.00000000e+00,
#        5.20841236e+00, 0.00000000e+00, 1.49104984e+00, 8.71677739e-01,
#        2.06164715e+02, 0.00000000e+00, 9.28128452e+00, 0.00000000e+00,
#        0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 6.43242128e+00,
#        3.86811886e+00, 1.34703835e+02, 7.07271105e+01, 3.85298816e+00,
#        6.82103007e+00, 3.48548969e+00, 7.93649779e+02, 8.26458359e+00,
#        7.20151304e-01, 3.01970134e+00, 0.00000000e+00, 0.00000000e+00,
#        0.00000000e+00, 3.47458726e+01])

# %%
scipy.special.softmax(bidding_prices_i)
# Out:
# array([0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        3.85025358e-320, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        1.43008960e-312, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 2.37822746e-308, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 5.76481028e-278, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        7.21902755e-256, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 6.65905840e-287, 1.09313662e-314, 0.00000000e+000,
#        0.00000000e+000, 0.00000000e+000, 1.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 0.00000000e+000])

# %% [markdown]
# The bidding prices are so 'inequal' that softmax 'breaks'

# %%
softmax_bids = scipy.special.softmax(bidding_prices_i)
softmax_bids.shape
# Out:
# (50,)

# %%
softmax_asks = scipy.special.softmax(-asking_prices_i)
softmax_asks.shape
# Out:
# (13,)

# %%
np.random.choice(
    self.exchanging_agent_list[self.buyers_mask],  
    p=softmax_bids, 
    size=N_transacting_agents, 
    replace=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 np.random.choice(
#       2     self.exchanging_agent_list[self.buyers_mask],
#       3     p=softmax_bids,
#       4     size=N_transacting_agents,
#       5     replace=False)
#
# File mtrand.pyx:1007, in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Fewer non-zero entries in p than size

# %%
self.exchanging_agent_list[self.buyers_mask].shape
# Out:
# (50,)

# %%
softmax_bids
# Out:
# array([0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        3.85025358e-320, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        1.43008960e-312, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 2.37822746e-308, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 5.76481028e-278, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        7.21902755e-256, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 6.65905840e-287, 1.09313662e-314, 0.00000000e+000,
#        0.00000000e+000, 0.00000000e+000, 1.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 0.00000000e+000, 0.00000000e+000, 0.00000000e+000,
#        0.00000000e+000, 0.00000000e+000])

# %%
softmax_asks
# Out:
# array([0.08693602, 0.0869289 , 0.0869454 , 0.08694167, 0.08694199,
#        0.08693346, 0.08685381, 0.03527204, 0.0869454 , 0.0869454 ,
#        0.00850876, 0.08694393, 0.08690321])

# %%
np.random.choice(self.exchanging_agent_list[self.sellers_mask],  p=softmax_asks, size=N_transacting_agents, replace=False)
# Out:
# array([<Agents.Agent object at 0x000001F1EFB6F370>,
#        <Agents.Agent object at 0x000001F1F0BE5F90>,
#        <Agents.Agent object at 0x000001F1F0BE4430>,
#        <Agents.Agent object at 0x000001F1EFB6ED70>,
#        <Agents.Agent object at 0x000001F1F0BE4130>,
#        <Agents.Agent object at 0x000001F1F0BE5E10>,
#        <Agents.Agent object at 0x000001F1EFB6DFF0>,
#        <Agents.Agent object at 0x000001F1EFB6FC70>,
#        <Agents.Agent object at 0x000001F1EFB6EBF0>,
#        <Agents.Agent object at 0x000001F1EFB6F1F0>,
#        <Agents.Agent object at 0x000001F1F0BE5090>,
#        <Agents.Agent object at 0x000001F1F0BE5210>,
#        <Agents.Agent object at 0x000001F1F0BE5810>], dtype=object)

# %% [markdown]
# Plotting

# %%
np.nanmean(p, axis=0)

# %%
def plot_market(i, *, ps=10, log=False, supply_demand=False, show_M_total=False):

    f, ax = plt.subplots(1, figsize=(10,4)) #(2,1)

    ax.plot(ME_df[:,i], c='C0', label=f'$\Delta M_{i}$')
    ax.plot(QE_df[:,i], c='C1', label=f'$\Delta Q_{i}$')
    ax.plot(ntries_df, c='k', label='Tries', lw='0.5')

    #ax.scatter(np.arange(0,T-1), p[:,i], c='g', label=f'$p_{i}$', s=ps)
    ax.plot(p[:,i], c='g', label=f'$p_{i}$')
    
    if supply_demand:
        ax.plot(supply_df[:,i], c='blue', ls='--', label=f'Supply')
        ax.plot(demand_df[:,i], c='orange', ls='--', label=f'Demand')
        
    if show_M_total:
        ax.axhline(M_total, c='g', ls=':', label='$M_{total}$')

    ax.legend(bbox_to_anchor=(1, 0.5))
    
    if log:
        plt.yscale('log')
        
    plt.title(f'Market for Commodity {i}')
    plt.xlabel('t')
    plt.ylabel('$M$, $Q$')

# %%
def plot_prices(i, *, log=False):

    p_buy, p_sell = p_df[0], p_df[1]

    lw = 1.0

    for n in range(NA):
        plt.plot(p_sell[:,n][:,i], c='C1', lw=lw/5.)
    plt.plot(M_df[:-1, 0:NA].sum(axis=1), c='g', ls='-')

    for n in range(NB):
        plt.plot(p_buy[:,NA+n][:,i], c='C0', lw=lw/5.)
    plt.plot(M_df[:-1, NA:].sum(axis=1), c='lime', ls='-')

    plt.plot(p[:,i], c='g', lw=lw)
    plt.ylim(ymin=0.007)

    plt.title(f'Commodity {i}. Blue Bidding Price. Orange Asking Price')
    if log:
        plt.yscale('log')

# %%
plot_market(0, log=True, supply_demand=True, show_M_total=True)
#plt.ylim(ymin=0.007, ymax=2e4)
plt.show()

# %%
plot_prices(0, log=True)

# %%
plot_market(1, log=True, supply_demand=True, show_M_total=False)
#plt.ylim(ymin=0.007, ymax=2e4)
plt.show()

# %%
plot_prices(1, log=True)

# %%
plt.plot(p[:,0], c='g', label='$p_1$')
plt.plot(p[:,1], c='turquoise', label='$p_2$')
plt.ylabel('$p$')
plt.yscale('log')
plt.legend()

# %%
plt.plot(p[:,0]/p[:,1], c='g')
plt.ylabel('$p_{1}/p_{2}$')
plt.yscale('log')

# %%
plt.hist(p[:,0], color='C0', histtype='step')
plt.hist(p[:,1], color='C1', histtype='step')
plt.hist(p[:,0]/p[:,1], color='k', histtype='step')

# %%
assert False

# %%
#ME_df

# %%
#QE_df

# %%
x_data=[]
xx_data=[]

B = 10000

theta = 0.01

x = 1

for _ in range(B):
    

    th = np.random.choice([-theta, theta])
    
    x *= (1+th)
    x_data.append(x)
    
    theta2 = theta #theta/(1+theta)
    
    xx = (1+theta)**_ * (1-theta2)**_
    
    xx_data.append(xx)

x_data=np.array(x_data)
xx_data=np.array(xx_data)

# %%
xx

# %%
plt.plot(x_data)

# %%
plt.plot(xx_data)

# %%
def randomize_agent_bid(agent, i):
    
    #new_bid = np.random.uniform(M_min, agent.M)
    new_bid = random_bid_list[eps_agent_list < epsilon]
    agent.p_buy[i] = new_bid
    
def randomize_agent_ask(agent, i):
    
    new_ask = np.random.uniform(M_min, agent.M)
    agent.p_sell[i] = new_ask
    
epsilon = 1e-2
eps_agent_list = np.random.uniform(0,1, Nm)

    
bid_dist_i = agent_data[:, 0, i]

mean_bid = bid_dist_i.mean()
std_bid = bid_dist_i.std()

random_bid_list = std_bid/2.*np.random.standard_cauchy(Nm) + mean_bid

[randomize_agent_bid(agent, i) for agent in exchanging_agent_list[eps_agent_list < epsilon]]
