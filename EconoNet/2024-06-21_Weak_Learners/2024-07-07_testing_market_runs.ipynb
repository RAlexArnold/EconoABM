# %%
import PriceRatioExperiment as PRE

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats
import random

# %%
N = 100 # Number of agents

T = 100 # Length of Simulation

Mmax = 100 # Max possible money per agent
theta = 0.1 # Proportional change of prices in market
epsilon = 0.005 # Proportion of randomizing prices for agent
max_tries = 100 # Max number of market attempts

# Define Productivity Coefficients (Direct Labor Coefficients)
l1 = 0.5
l2 = 0.5

# Define the desired consumption rate
c1 = 1.0
c2 = 1.0

# The macro-economic condition must be satisfied
# l1*c1 + l2*c2 <= 1.0
print(l1*c1 + l2*c2)
# Out:
# 1.0

# %%
# Inititialize Market Simulation
sim = PRE.PriceRatioExperiment(N, l1, l2, c1, c2, Mmax=Mmax, theta=theta, epsilon=epsilon, max_tries=max_tries)

# %%
Me_df, Qe_df, ntries_df, p_df = sim.run_experiment(T)
# Out:
# C:\Users\Alex\Documents\Research\EconoABM\EconoNet\2024-06-21_Weak_Learners\PriceRatioExperiment.py:96: RuntimeWarning: invalid value encountered in divide
#   self.p_df = self.Me_df/self.Qe_df

# %%
f, ax = plt.subplots()
ax.plot(ntries_df, lw=0.5)
ax.set_xlabel('$t$')
ax.set_ylabel('Market Attempts')
# Out:
# Text(0, 0.5, 'Market Attempts')

# %%
f, ax = plt.subplots(2,1, figsize=(8,6))
for i in range(2):
    ax[0].plot(Me_df[:,i], label=f'$M^E_{i+1}$', lw=0.5)
    ax[1].plot(Qe_df[:,i], label=f'%Q^E_{i+1}$', lw=0.5)
    
    
ax[0].legend()
ax[0].set_yscale('log')
ax[0].set_xlabel('$t$')
ax[0].set_ylabel('Money Used in Market')
# Out:
# Text(0, 0.5, 'Money Used in Market')

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 assert False
#
# AssertionError:

# %%
N = 100
num = 11

prod_values = np.logspace(-1, 1, num)
labor_coeffs = 1.0/prod_values

# %%
T = 500

n = len(labor_coeffs)
n = n*n

l_ratio_df = []
p_ratio_df = []
p_ratio_std_df = []
c1_df = []

for l1 in labor_coeffs:
    
    print(l1)
    
    for l2 in labor_coeffs:
        
        try:
    
            c1 = np.random.uniform(0, 1.0/l1)
            c2 = 1.0/l2*(1.0 - l1*c1)

            pre = PRE.PriceRatioExperiment(N, l1, l2, c1, c2)
            print(l1, l2)
            print(c1, c2)
            print(pre.N1, pre.N2)
            print(l1*c1 + l2*c2)
            print()

            Me_df, Qe_df, ntries_df, p_df = pre.run_experiment(T)

            p_ratio     = np.nanmean(p_df[:,0]/p_df[:,1])
            p_ratio_std = np.nanstd(p_df[:,0]/p_df[:,1])

            
        except:
            
            print('Fail for')
            print(l1, l2)
            print()
            
            p_ratio = np.nan
            p_ratio_std = np.nan
        
        l_ratio_df.append(l1/l2)
        p_ratio_df.append(p_ratio)
        p_ratio_std_df.append(p_ratio_std)
        c1_df.append(c1)
# Out:
# 10.0
# 10.0 10.0
# 0.0866376932640507 0.013362306735949304
# 87 13
# 1.0
# C:\Users\Alex\Documents\Research\EconoABM\EconoNet\2024-01-28_Testing_Price_Ratios\PriceRatioExperiment.py:96: RuntimeWarning: invalid value encountered in divide
#   self.p_df = self.Me_df/self.Qe_df
# 10.0 6.3095734448019325
# 0.04346327478055587 0.08960467092434155
# 43 57
# 1.0
#
# 10.0 3.9810717055349727
# 0.04618165189754027 0.13518557836482797
# 46 54
# 1.0
#
# 10.0 2.5118864315095797
# 0.03858906511198376 0.24448133529313196
# 39 61
# 1.0
#
# 10.0 1.5848931924611132
# 0.0658156632233302 0.2156885835542419
# 66 34
# 1.0
#
# 10.0 1.0
# 0.014702711841608741 0.8529728815839126
# 15 85
# 1.0
#
# 10.0 0.630957344480193
# 0.08493818598093408 0.23871366504932953
# 85 15
# 1.0
#
# 10.0 0.3981071705534971
# 0.0824359981475151 0.4411877793626597
# 82 18
# 1.0
#
# 10.0 0.25118864315095796
# 0.001202286948348108 3.9332078000149466
# 1 99
# 0.9999999999999999
#
# 10.0 0.15848931924611132
# 0.049344400304956626 3.196152266663626
# 49 51
# 1.0
#
# 10.0 0.1
# 0.09766391454782666 0.2336085452173342
# 98 2
# 1.0
#
# 6.3095734448019325
# 6.3095734448019325 10.0
# 0.11068379963837287 0.030163243703194488
# 70 30
# 1.0
#
# 6.3095734448019325 6.3095734448019325
# 0.13651163130809257 0.021977687938018776
# 86 14
# 1.0
#
# 6.3095734448019325 3.9810717055349727
# 0.08996174728235513 0.10860888230124628
# 57 43
# 1.0
#
# 6.3095734448019325 2.5118864315095797
# 0.0861705370386619 0.18165656777018874
# 54 46
# 1.0
#
# 6.3095734448019325 1.5848931924611132
# 0.07923922893454666 0.3155002922004615
# 50 50
# 1.0
#
# 6.3095734448019325 1.0
# 0.026795024909890646 0.8309348223757477
# 17 83
# 1.0
#
# 6.3095734448019325 0.630957344480193
# 0.11578215197483789 0.42707167271273483
# 73 27
# 1.0
#
# 6.3095734448019325 0.3981071705534971
# 0.11949102952295611 0.6180812389985497
# 75 25
# 1.0
#
# 6.3095734448019325 0.25118864315095796
# 0.0984388414281825 1.508399804365225
# 62 38
# 1.0
#
# 6.3095734448019325 0.15848931924611132
# 0.15347432491599072 0.1996505203106154
# 97 3
# 1.0
#
# 6.3095734448019325 0.1
# 0.024383497469712637 8.46150531873706
# 15 85
# 1.0
#
# 3.9810717055349727
# 3.9810717055349727 10.0
# 0.1854813248039416 0.026158554591788598
# 74 26
# 1.0
#
# 3.9810717055349727 6.3095734448019325
# 0.22020458857634537 0.01954961679562697
# 88 12
# 1.0
#
# 3.9810717055349727 3.9810717055349727
# 0.07430890510466209 0.17687973804629592
# 30 70
# 1.0
#
# 3.9810717055349727 2.5118864315095797
# 0.21927884909442374 0.05057361537303724
# 87 13
# 1.0
#
# 3.9810717055349727 1.5848931924611132
# 0.17202137598677522 0.19885918420940468
# 68 32
# 1.0
#
# 3.9810717055349727 1.0
# 0.14272150629056093 0.43181544953531625
# 57 43
# 1.0
#
# 3.9810717055349727 0.630957344480193
# 0.17354650547193204 0.489888770097238
# 69 31
# 1.0
#
# 3.9810717055349727 0.3981071705534971
# 0.12383051297186938 1.2735813017908866
# 49 51
# 1.0
#
# 3.9810717055349727 0.25118864315095796
# 0.21711285989579707 0.5400647690888498
# 86 14
# 1.0
#
# 3.9810717055349727 0.15848931924611132
# 0.18852757404715928 1.5739748926571622
# 75 25
# 1.0
#
# 3.9810717055349727 0.1
# 0.09131556889252818 6.364661724071265
# 36 64
# 1.0
#
# 2.5118864315095797
# 2.5118864315095797 10.0
# 0.09640498801677377 0.07578416186708224
# 24 76
# 1.0
#
# 2.5118864315095797 6.3095734448019325
# 0.061701770334870024 0.13392540203995454
# 15 85
# 1.0
#
# 2.5118864315095797 3.9810717055349727
# 0.3560208030578112 0.026554702673895623
# 89 11
# 1.0
#
# 2.5118864315095797 2.5118864315095797
# 0.21294784341810635 0.18515932713539096
# 53 47
# 1.0
#
# 2.5118864315095797 1.5848931924611132
# 0.06083203180176921 0.5345450713939913
# 15 85
# 0.9999999999999999
#
# 2.5118864315095797 1.0
# 0.020524143340378623 0.9484456828249452
# 5 95
# 1.0
#
# 2.5118864315095797 0.630957344480193
# 0.32865458548268767 0.27649572130166106
# 83 17
# 1.0
#
# 2.5118864315095797 0.3981071705534971
# 0.1720489937907232 1.426330669082741
# 43 57
# 1.0
#
# 2.5118864315095797 0.25118864315095796
# 0.24332003074536585 1.5478713980813148
# 61 39
# 1.0
#
# 2.5118864315095797 0.15848931924611132
# 0.27724707042823393 1.9155034992869853
# 70 30
# 1.0
#
# 2.5118864315095797 0.1
# 0.024114988097987438 9.394258886006504
# 6 94
# 1.0
#
# 1.5848931924611132
# 1.5848931924611132 10.0
# 0.30353881894992313 0.05189233921985806
# 48 52
# 1.0
#
# 1.5848931924611132 6.3095734448019325
# 0.2462254567311136 0.09664028086059802
# 39 61
# 1.0
#
# 1.5848931924611132 3.9810717055349727
# 0.573961559701758 0.022690430611619
# 91 9
# 1.0
#
# 1.5848931924611132 2.5118864315095797
# 0.0013653106842104437 0.39724571774979744
# 0 100
# 1.0
# C:\Users\Alex\AppData\Local\Temp\ipykernel_2672\86730695.py:31: RuntimeWarning: Mean of empty slice
#   p_ratio     = np.nanmean(p_df[:,0]/p_df[:,1])
# C:\Users\Alex\anaconda3\envs\pytorchgame3.10\lib\site-packages\numpy\lib\nanfunctions.py:1879: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = nanvar(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# 1.5848931924611132 1.5848931924611132
# 0.07121856502328501 0.5597387794569083
# 11 89
# 0.9999999999999999
#
# 1.5848931924611132 1.0
# 0.09834338281731671 0.8441362420492375
# 16 84
# 1.0
#
# 1.5848931924611132 0.630957344480193
# 0.05338545970261384 1.4507949805942169
# 8 92
# 1.0
#
# 1.5848931924611132 0.3981071705534971
# 0.4375251215518993 0.7700675496385649
# 69 31
# 1.0
#
# 1.5848931924611132 0.25118864315095796
# 0.18591583075779294 2.8080221168173125
# 29 71
# 1.0
#
# 1.5848931924611132 0.15848931924611132
# 0.5840863946389994 0.4687094984119402
# 93 7
# 1.0
#
# 1.5848931924611132 0.1
# 0.36390457897677153 4.232501100742873
# 58 42
# 1.0
#
# 1.0
# 1.0 10.0
# 0.5145910076455814 0.04854089923544186
# 51 49
# 1.0
#
# 1.0 6.3095734448019325
# 0.02336595453855772 0.15478606501775974
# 2 98
# 0.9999999999999999
#
# 1.0 3.9810717055349727
# 0.05025363732829813 0.23856550017706246
# 5 95
# 1.0
#
# 1.0 2.5118864315095797
# 0.7102835348289165 0.11533820221202092
# 71 29
# 1.0
#
# 1.0 1.5848931924611132
# 0.8939593959707303 0.06690709792538373
# 89 11
# 1.0
#
# 1.0 1.0
# 0.5927781496430353 0.4072218503569647
# 59 41
# 1.0
#
# 1.0 0.630957344480193
# 0.6407686801677366 0.5693432733209755
# 64 36
# 1.0
#
# 1.0 0.3981071705534971
# 0.4972318527481242 1.262896487277198
# 50 50
# 1.0
#
# 1.0 0.25118864315095796
# 0.43733149518308445 2.2400236641222913
# 44 56
# 1.0
#
# 1.0 0.15848931924611132
# 0.17979210446559235 5.1751619568807765
# 18 82
# 0.9999999999999999
#
# 1.0 0.1
# 0.2516104119775896 7.483895880224104
# 25 75
# 1.0
#
# 0.630957344480193
# 0.630957344480193 10.0
# 0.22756061386940857 0.08564189593646754
# 14 86
# 1.0
#
# 0.630957344480193 6.3095734448019325
# 1.5180422126993298 0.006685097976178426
# 96 4
# 1.0
#
# 0.630957344480193 3.9810717055349727
# 0.616024654863733 0.1535553149627843
# 39 61
# 1.0
#
# 0.630957344480193 2.5118864315095797
# 0.18827412953134756 0.3508148474160904
# 12 88
# 1.0
#
# 0.630957344480193 1.5848931924611132
# 0.14042038187943298 0.5750549835621307
# 9 91
# 0.9999999999999999
#
# 0.630957344480193 1.0
# 0.09747952660409608 0.9384945767526932
# 6 94
# 1.0
#
# 0.630957344480193 0.630957344480193
# 0.25894192615222006 1.325951266308894
# 16 84
# 1.0
#
# 0.630957344480193 0.3981071705534971
# 0.7134117981216579 1.3812049292451232
# 45 55
# 1.0
#
# 0.630957344480193 0.25118864315095796
# 0.5955478470970326 2.4851231490971952
# 38 62
# 0.9999999999999999
#
# 0.630957344480193 0.15848931924611132
# 0.21526257966264356 5.452597679646515
# 14 86
# 0.9999999999999999
#
# 0.630957344480193 0.1
# 1.2476909303921946 2.1276024382771954
# 79 21
# 1.0
#
# 0.3981071705534971
# 0.3981071705534971 10.0
# 0.3618263055497092 0.08559543532657803
# 14 86
# 1.0
#
# 0.3981071705534971 6.3095734448019325
# 1.885251806435625 0.039537971899600476
# 75 25
# 1.0
#
# 0.3981071705534971 3.9810717055349727
# 1.8945349662911304 0.06173514652184506
# 75 25
# 1.0
#
# 0.3981071705534971 2.5118864315095797
# 2.1757923433925224 0.05326732322831519
# 87 13
# 1.0
#
# 0.3981071705534971 1.5848931924611132
# 0.5403811551393064 0.4952197353364037
# 22 78
# 1.0
#
# 0.3981071705534971 1.0
# 2.096012023356903 0.1655625839352729
# 83 17
# 1.0
#
# 0.3981071705534971 0.630957344480193
# 1.2196020119909947 0.8153763456525752
# 49 51
# 1.0
#
# 0.3981071705534971 0.3981071705534971
# 2.0730133815785177 0.4388730499310636
# 83 17
# 1.0
#
# 0.3981071705534971 0.25118864315095796
# 0.2693915986024396 3.5541147948037497
# 11 89
# 0.9999999999999999
#
# 0.3981071705534971 0.15848931924611132
# 1.1214747130937368 3.492556329700678
# 45 55
# 1.0
#
# 0.3981071705534971 0.1
# 2.0318791773789537 1.910943297870975
# 81 19
# 1.0
#
# 0.25118864315095796
# 0.25118864315095796 10.0
# 1.9401912650888458 0.05126459886689923
# 49 51
# 1.0
#
# 0.25118864315095796 6.3095734448019325
# 2.1036913059581837 0.07473985989281096
# 53 47
# 1.0
#
# 0.25118864315095796 3.9810717055349727
# 3.1307089373478703 0.05365426340601606
# 79 21
# 1.0
#
# 0.25118864315095796 2.5118864315095797
# 1.7688512090939204 0.22122204964410527
# 44 56
# 1.0
#
# 0.25118864315095796 1.5848931924611132
# 1.0814895819932766 0.45955279685831746
# 27 73
# 1.0
#
# 0.25118864315095796 1.0
# 2.8136614679472745 0.2932401935801916
# 71 29
# 1.0
#
# 0.25118864315095796 0.630957344480193
# 1.7367696075115693 0.8934727581113752
# 44 56
# 1.0
#
# 0.25118864315095796 0.3981071705534971
# 2.519701917870279 0.9220620005284997
# 63 37
# 1.0
#
# 0.25118864315095796 0.25118864315095796
# 3.297068981277024 0.6840027242579495
# 83 17
# 1.0
#
# 0.25118864315095796 0.15848931924611132
# 2.0680511122409126 3.031933315349677
# 52 48
# 1.0
#
# 0.25118864315095796 0.1
# 2.123329225256271 4.666438129451025
# 53 47
# 1.0
#
# 0.15848931924611132
# 0.15848931924611132 10.0
# 1.6596851794080758 0.0736957625752754
# 26 74
# 1.0
#
# 0.15848931924611132 6.3095734448019325
# 5.72479896013377 0.01468887093530969
# 91 9
# 1.0
#
# 0.15848931924611132 3.9810717055349727
# 4.780270193757699 0.0608826590191485
# 76 24
# 1.0
#
# 0.15848931924611132 2.5118864315095797
# 0.9873604027180898 0.3358089407791073
# 16 84
# 0.9999999999999999
#
# 0.15848931924611132 1.5848931924611132
# 5.608658672778396 0.07009147720235379
# 89 11
# 1.0
#
# 0.15848931924611132 1.0
# 3.7868558339213627 0.399823796798638
# 60 40
# 1.0
#
# 0.15848931924611132 0.630957344480193
# 5.351508277950282 0.24065508931166255
# 85 15
# 1.0
#
# 0.15848931924611132 0.3981071705534971
# 5.201714139842627 0.4410467332687136
# 82 18
# 1.0
#
# 0.15848931924611132 0.25118864315095796
# 2.961011416343747 2.1127998053031867
# 47 53
# 1.0
#
# 0.15848931924611132 0.15848931924611132
# 1.047838875654541 5.261734569147393
# 17 83
# 1.0
#
# 0.15848931924611132 0.1
# 4.351209430485517 3.1037977946509065
# 69 31
# 1.0
#
# 0.1
# 0.1 10.0
# 8.452149496978532 0.015478505030214685
# 85 15
# 1.0
#
# 0.1 6.3095734448019325
# 0.3507999013685903 0.15292951549016026
# 4 96
# 1.0
#
# 0.1 3.9810717055349727
# 1.3591336225157036 0.2170487501009014
# 14 86
# 1.0
#
# 0.1 2.5118864315095797
# 5.084648616232831 0.19568366316677654
# 51 49
# 1.0
#
# 0.1 1.5848931924611132
# 0.34012647358342973 0.609496814824232
# 3 97
# 1.0
#
# 0.1 1.0
# 5.981953197220636 0.40180468027793637
# 60 40
# 1.0
#
# 0.1 0.630957344480193
# 7.529751514339335 0.3915080008610963
# 75 25
# 1.0
#
# 0.1 0.3981071705534971
# 7.06233225189038 0.7379087756759858
# 71 29
# 1.0
#
# 0.1 0.25118864315095796
# 0.716058689699457 3.696003606628478
# 7 93
# 1.0
#
# 0.1 0.15848931924611132
# 5.393488595530921 2.906512203081536
# 54 46
# 1.0
#
# 0.1 0.1
# 4.1316795473412355 5.8683204526587645
# 41 59
# 1.0

# %%
plt.scatter(l_ratio_df, p_ratio_df, s = 0.5, c='k')
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Productivity Ratios ($l_1/l_2$)')
plt.ylabel('Price Ratios ($p_1/p_2$)')

x = np.logspace(-3,3,10)
plt.plot(x,x, c='k', lw=0.1)
plt.xlim(5e-3, 2e2)
plt.ylim(5e-3, 2e2)
# Out:
# (0.005, 200.0)

# %%
plt.scatter(p_ratio_df, p_ratio_std_df, c='k', s=0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Price Ratios ($p_1/p_2$)')
plt.ylabel('Price Ratio Standard Deviations')
# Out:
# Text(0, 0.5, 'Price Ratio Standard Deviations')

# %%
plt.scatter(p_ratio_df, c1_df, c='k', s=0.5)
plt.xscale('log')
plt.yscale('log')
plt.xlabel('Price Ratios ($p_1/p_2$)')
plt.ylabel(r'$\bar{c}_1$')
# Out:
# Text(0, 0.5, '$\\bar{c}_1$')
