# %%
import Agents
import Markets

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats

def add_price_data(df, t):
    
    #pA_buy, pA_sell, pB_buy, pB_sell = df
    p_buy, p_sell = df
    
    for v, agent in enumerate(agent_list):
        p_buy[t][v] = agent.p_buy
        p_sell[t][v] = agent.p_sell

# %%
def add_quant_data(df, t):

    for v,agent in enumerate(agent_list):

        df[t][v] = agent.Q
    
    
    #print(agent_list[0].Q)
    
def add_deficit_data(df, t):

    for v,agent in enumerate(agent_list):

        df[t][v] = agent.D
    
def add_money_data(df, t):
    
    for v,agent in enumerate(agent_list):

        df[t][v] = agent.M
    
def reset():
    
    for agent in agentA_list:
        agent.Q = QA
        agent.D = DA
        
        p1buy_A_0 = 10# np.random.uniform(0, agent.M)
        p2buy_A_0 = 10# np.random.uniform(0, agent.M)
        p1sell_A_0 = 10# np.random.uniform(0, agent.M)
        p2sell_A_0 = 10# np.random.uniform(0, agent.M)
        agent.p_buy = [p1buy_A_0, p2buy_A_0]#np.random.uniform(M, size=n) #[15, 10]
        agent.p_sell = [p1sell_A_0, p2sell_A_0]#np.random.uniform(M, size=n) #[25, 30]
        
    for agent in agentB_list:
        agent.Q = QB
        agent.D = DB
        
        p1buy_B_0 = 10# np.random.uniform(0, agent.M)
        p2buy_B_0 = 10# np.random.uniform(0, agent.M)
        p1sell_B_0 = 10# np.random.uniform(0, agent.M)
        p2sell_B_0 = 10# np.random.uniform(0, agent.M)
        agent.p_buy = [p1buy_B_0, p2buy_B_0]#np.random.uniform(M, size=n) #[10, 15]
        agent.p_sell = [p1sell_B_0, p2sell_B_0]#np.random.uniform(M, size=n) #[30, 25]
    
    market.reset()

# %%
def plot_market(i, *, ps=10, log=False):

    f, ax = plt.subplots(1, figsize=(10,4)) #(2,1)

    ax.plot(ME_df[:,i], c='C0', label=f'$\Delta M_{i}$')
    ax.plot(QE_df[:,i], c='C1', label=f'$\Delta Q_{i}$')
    ax.plot(ntries_df, c='k', label='Tries', lw='0.5')

    p = ME_df[:,i]/QE_df[:,i]
    ax.scatter(np.arange(0,T), p, c='g', label='f$p_{i}$', s=ps)

    ax.legend()
    
    if log:
        plt.yscale('log')
        
    plt.title(f'Market for Commodity {i}')
    plt.xlabel('t')
    plt.ylabel('$M$, $Q$')


def plot_prices(p_df, i, *, A=0, B=1, ps=10, log=False, includeM=True):

    'A sells i=0 and buys i=1, and vice versa for B'

    if i == 0:
        plt.plot(p_df[1][:,A,i], c='C0', ls='-.', label=f"A's Selling Price for {i}")
        plt.plot(p_df[0][:,B,i], c='C1', ls='-', label=f"B's Buying Price for {i}")

    elif i == 1:
        plt.plot(p_df[0][:,A,i], c='C0', ls='-', label=f"A's Buying Price for {i}")
        plt.plot(p_df[1][:,B,i], c='C1', ls='-.', label=f"B's Selling Price for {i}")

    if includeM:
        plt.plot(M_df[:,A], c='C0', ls=':', lw=0.5, label=f'$M_A$')
        plt.plot(M_df[:,B], c='C1', ls=':', lw=0.5, label=f'$M_B$')
    
    p = ME_df[:,i]/QE_df[:,i]
    plt.scatter(np.arange(T)+0.5, p, c='g', s=ps)
    
    plt.legend()
    
    if log:
        plt.yscale('log')

    plt.title(f'Market Prices for Commodity {i}')
    plt.xlabel('t')
    plt.ylabel('Prices')
    
def plot_quantities(Q_df, D_df, i, *, A=0, B=1):

    plt.plot(Q_df[:,A,i], c='C0', ls='-', label=f"A's Q{i}")
    plt.plot(D_df[:,A,i], c='C0', ls=':', label=f"A's D{i}")

    plt.plot(Q_df[:,B,i], c='C1', ls='-', label=f"B's Q{i}")
    plt.plot(D_df[:,B,i], c='C1', ls=':', label=f"B's D{i}")

    plt.legend()

    plt.title(f'Quantities for Commodity {i}')
    plt.xlabel('t')
    plt.ylabel('Q,D')

# %%
NA = 3#0
NB = 3#0
N = NA+NB
M = 1000/N

n = 2

QA1 = 1
QA2 = 0

QB1 = 0
QB2 = 1

QA_0 = np.array([QA1, QA2])
QB_0 = np.array([QB1, QB2])

QA = np.copy(QA_0)
QB = np.copy(QB_0)

qA = np.array([1, 0])*0
qB = np.array([0, 1])*0

cA = np.array([0, 1])*0
cB = np.array([1, 0])*0

DA = np.array([0, 2]) #cA.copy()
DB = np.array([2, 0]) #cB.copy()


#p1buy_A_0, p2buy_A_0 = 10,10
#p1sell_A_0, p2sell_A_0 = 10,10

#p1buy_B_0, p2buy_B_0 = 10,10
#p1sell_B_0, p2sell_B_0 = 10,10

# %%
agentA_list = [Agents.Agent(QA, DA, M, n_actions=1, input_dims=[1]) for agent in range(NA)]
agentB_list = [Agents.Agent(QB, DB, M, n_actions=1, input_dims=[1]) for agent in range(NB)]

# %%
agent_list = agentA_list + agentB_list


#agentB = agentB_list[0]
#agentA2 = agentA_list[1]

#agent_list[1] = agentB
#agent_list[NA] = agentA2

# %%
Q = np.zeros(n)
for agent in agent_list:
    Q += agent.Q
    
Q
# Out:
# array([3., 3.])

# %%
verbose = True
alpha = 0.5
beta = 0.5
gamma = 1.00
epsilon = 0.00
max_agent_tries = 1 #10# 100
max_tries = N*max_agent_tries
price_adjust_method = 'proportional_random' #'step_random'
min_price = 1e-5

# %%
market = Markets.Market(n, 
                        verbose=verbose, 
                        minimum_price=min_price, 
                        alpha=alpha, 
                        beta=beta, 
                        gamma=gamma, 
                        epsilon=epsilon, 
                        max_agent_tries=max_agent_tries, 
                        max_tries=max_tries,
                        price_adjust_method=price_adjust_method)
print(f'Market has {max_tries} max tries')

ExchangeDict = {agent : 2 for agent in agent_list}
# Out:
# Market has 6 max tries

# %%
M
# Out:
# 166.66666666666666

# %%
T = 2 #200

reset()

# Setup data
#pA_buy, pA_sell, pB_buy, pB_sell = np.zeros((T, 2)), np.zeros((T, 2)), np.zeros((T, 2)), np.zeros((T, 2))
p_buy, p_sell = np.zeros((T, N, n)), np.zeros((T, N, n))
p_df = (p_buy, p_sell)

#QA_df, QB_df = np.zeros((T, 2)), np.zeros((T, 2))
Q_df = np.zeros((T, N, n))

#DA_df, DB_df = np.zeros((T, 2)), np.zeros((T, 2))
D_df = np.zeros((T, N, n))

M_df = np.zeros((T, N))

ME_df = np.zeros((T,2))
QE_df = np.zeros((T,2))
sE_df = np.zeros((T,2))
ntries_df = []


add_price_data(p_df, 0)
add_quant_data(Q_df, 0)
add_deficit_data(D_df, 0)
add_money_data(M_df, 0)

# Run market
for t in range(T-1):
    
    # Market action occurs at half-time interval
    ME, QE, stn_dev, ntries = market.run_exchange(ExchangeDict)
    
    # Reset quantities
    for agentA in agentA_list:
        pass
        #agentA.Q = np.maximum(np.zeros(n), agentA.Q + qA - cA) #np.array([QA1, QA2])*np.exp(-0.005*t)
    for agentB in agentB_list:
        #agentB.Q = np.maximum(np.zeros(n), agentB.Q + qB - cB) #np.array([QB1, QB2])*np.exp(0.001*t)
        pass
    #agent_list[0].D = DA.copy()#*t
    #agent_list[1].D = DB.copy()*t
    
    #print(QA, agent_list[0].Q)
    
    add_price_data(p_df, t+1)
    add_quant_data(Q_df, t+1)
    add_deficit_data(D_df, t+1)
    add_money_data(M_df, t+1)
    
    # Market action occurs at half-time interval
    ME_df[t] = ME
    QE_df[t] = QE
    sE_df[t] = stn_dev
    ntries_df.append(ntries)
# Out:
# ---Begin Exchanging---
#
# {<Agents.Agent object at 0x000001CBB6AA29E0>: array([-1.,  2.]), <Agents.Agent object at 0x000001CBB6AA3D00>: array([-1.,  2.]), <Agents.Agent object at 0x000001CBB6AA20B0>: array([-1.,  2.]), <Agents.Agent object at 0x000001CBB6AA09D0>: array([ 2., -1.]), <Agents.Agent object at 0x000001CBB6AA29B0>: array([ 2., -1.]), <Agents.Agent object at 0x000001CBB6AA2D10>: array([ 2., -1.])}
# <<attempt_exchange>>
# Q of Agents
# <Agents.Agent object at 0x000001CBB6AA29E0> [1 0] [0 2] 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA3D00> [1 0] [0 2] 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA20B0> [1 0] [0 2] 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA09D0> [0 1] [2 0] 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA29B0> [0 1] [2 0] 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA2D10> [0 1] [2 0] 166.66666666666666
#
# M of Agents
# <Agents.Agent object at 0x000001CBB6AA29E0> 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA3D00> 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA20B0> 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA09D0> 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA29B0> 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA2D10> 166.66666666666666
#
# Buyer Set
# {<Agents.Agent object at 0x000001CBB6AA29E0>: 2.0, <Agents.Agent object at 0x000001CBB6AA3D00>: 2.0, <Agents.Agent object at 0x000001CBB6AA20B0>: 2.0}
#
# Seller Set
# {<Agents.Agent object at 0x000001CBB6AA09D0>: -1.0, <Agents.Agent object at 0x000001CBB6AA29B0>: -1.0, <Agents.Agent object at 0x000001CBB6AA2D10>: -1.0}
#
# <<attempt_exchange()>>
# --Attempt An Exchange--
# Commodity 1
#
# Buyer:     <Agents.Agent object at 0x000001CBB6AA20B0>
# Buyer D:   [0 2]
# Buyer Q:   [1 0]
# Buyer E:   2
#            [-1  2]
#            [-1.  2.]
#
# Seller:    <Agents.Agent object at 0x000001CBB6AA2D10>
# Seller D:  [2 0]
# Seller Q:  [0 1]
# Seller E:  -1
#            [ 2 -1]
#            [ 2. -1.]
#
# Set Prices and Try an Exchange... <<set_prices_exchange()>>
#
# <<set_prices_exchange()>>
# Buyer <Agents.Agent object at 0x000001CBB6AA20B0>
# Seller <Agents.Agent object at 0x000001CBB6AA2D10>
# Buyer Price:   10.000
# Seller Price:  10.000
#
# -Scenario 2-
# Enact Exchange
# -Buyer Price 10.000 higher than Seller Price 10.000-
#
#      <<_exchange()>>
#      -Exchanging-
#      Commodity 1
#
#      pmax_buyer:     10.000
#      pmin_seller:    10.000
#      Settled Price:  10.0
#
#       Before Exchange
#      Buyer <Agents.Agent object at 0x000001CBB6AA20B0>
#      Buyer Money:    166.667
#      Buyer D:        [0 2]
#      Buyer Q:        [1 0]
#      Buyer Exchange: [-1  2]
#                      [-1.  2.]
#
#      Seller <Agents.Agent object at 0x000001CBB6AA2D10>
#      Seller Money:   166.667
#      Seller D:       [2 0]
#      Seller Q:       [0 1]
#      Seller Exchange:[ 2 -1]
#                      [ 2. -1.]
#
#      -Swap Items 1-
#      Market M 1:  10.000
#      Market Q 1:  1.0
#      Market p 1:  10.000
#
# <Agents.Agent object at 0x000001CBB6AA29E0> [1 0] [0 2] 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA3D00> [1 0] [0 2] 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA20B0> [1 0] [0 2] 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA09D0> [0 1] [2 0] 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA29B0> [0 1] [2 0] 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA2D10> [0 1] [2 0] 166.66666666666666
# None
# Buyer Q: [1 0]
# Buyer M: 166.66666666666666
# Seller Q: [0 1]
# Seller M: 166.66666666666666
# Buyer Q: [1 1]
# Buyer M: 156.66666666666666
# Seller Q: [0 0]
# Seller M: 176.66666666666666
# <Agents.Agent object at 0x000001CBB6AA29E0> [1 1] [0 2] 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA3D00> [1 1] [0 2] 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA20B0> [1 1] [0 2] 156.66666666666666
# <Agents.Agent object at 0x000001CBB6AA09D0> [0 0] [2 0] 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA29B0> [0 0] [2 0] 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA2D10> [0 0] [2 0] 176.66666666666666
# None
# {<Agents.Agent object at 0x000001CBB6AA29E0>: array([-1.,  2.]), <Agents.Agent object at 0x000001CBB6AA3D00>: array([-1.,  2.]), <Agents.Agent object at 0x000001CBB6AA20B0>: array([-1.,  2.]), <Agents.Agent object at 0x000001CBB6AA09D0>: array([ 2., -1.]), <Agents.Agent object at 0x000001CBB6AA29B0>: array([ 2., -1.]), <Agents.Agent object at 0x000001CBB6AA2D10>: array([ 2., -1.])}
# {<Agents.Agent object at 0x000001CBB6AA29E0>: array([-1.,  2.]), <Agents.Agent object at 0x000001CBB6AA3D00>: array([-1.,  2.]), <Agents.Agent object at 0x000001CBB6AA20B0>: array([-1,  1]), <Agents.Agent object at 0x000001CBB6AA09D0>: array([ 2., -1.]), <Agents.Agent object at 0x000001CBB6AA29B0>: array([ 2., -1.]), <Agents.Agent object at 0x000001CBB6AA2D10>: array([2, 0])}
#       After Exchange
#      Buyer           <Agents.Agent object at 0x000001CBB6AA20B0>
#      Buyer Money:    156.667
#      Buyer D:        [0 2]
#      Buyer Q:        [1 1]
#      Buyer Exchange: [-1  1]
#                      [-1  1]
#
#      Seller          <Agents.Agent object at 0x000001CBB6AA2D10>
#      Seller Money:   176.667
#      Seller D:       [2 0]
#      Seller Q:       [0 0]
#      Seller Exchange:[2 0]
#                      [2 0]
#                 ------------
#
#      Dec. Buyer Price to 9.915 and inc. Seller Price to 10.194
#
# Return to <<attempt_exchange()>>
# ...After Trying Exchange, Set New Agent Prices
# New Buyer Price:     9.915
# New Seller Price:    10.194
#
# Agent <Agents.Agent object at 0x000001CBB6AA20B0> attempts increased from 0 to 1
# Agent <Agents.Agent object at 0x000001CBB6AA20B0> has had 1/1 attempts. Tap Out. Exit
#
# Agent <Agents.Agent object at 0x000001CBB6AA2D10> attempts increased from 0 to 1
# Agent <Agents.Agent object at 0x000001CBB6AA2D10> has had 1/1 attempts. Tap Out. Exit
#
# {<Agents.Agent object at 0x000001CBB6AA29E0>: array([-1.,  2.]), <Agents.Agent object at 0x000001CBB6AA3D00>: array([-1.,  2.]), <Agents.Agent object at 0x000001CBB6AA09D0>: array([ 2., -1.]), <Agents.Agent object at 0x000001CBB6AA29B0>: array([ 2., -1.])}
#             ------------
# Total Exchange Attempts 1/6
#
# {<Agents.Agent object at 0x000001CBB6AA29E0>: array([-1.,  2.]), <Agents.Agent object at 0x000001CBB6AA3D00>: array([-1.,  2.]), <Agents.Agent object at 0x000001CBB6AA09D0>: array([ 2., -1.]), <Agents.Agent object at 0x000001CBB6AA29B0>: array([ 2., -1.])}
# <<attempt_exchange>>
# Q of Agents
# <Agents.Agent object at 0x000001CBB6AA29E0> [1 1] [0 2] 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA3D00> [1 1] [0 2] 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA09D0> [0 0] [2 0] 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA29B0> [0 0] [2 0] 166.66666666666666
#
# M of Agents
# <Agents.Agent object at 0x000001CBB6AA29E0> 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA3D00> 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA09D0> 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA29B0> 166.66666666666666
#
# Buyer Set
# {<Agents.Agent object at 0x000001CBB6AA09D0>: 2.0, <Agents.Agent object at 0x000001CBB6AA29B0>: 2.0}
#
# Seller Set
# {<Agents.Agent object at 0x000001CBB6AA29E0>: -1.0, <Agents.Agent object at 0x000001CBB6AA3D00>: -1.0}
#
# <<attempt_exchange()>>
# --Attempt An Exchange--
# Commodity 0
#
# Buyer:     <Agents.Agent object at 0x000001CBB6AA09D0>
# Buyer D:   [2 0]
# Buyer Q:   [0 0]
# Buyer E:   2
#            [2 0]
#            [ 2. -1.]
#
# Seller:    <Agents.Agent object at 0x000001CBB6AA29E0>
# Seller D:  [0 2]
# Seller Q:  [1 1]
# Seller E:  -1
#            [-1  1]
#            [-1.  2.]
#
# Set Prices and Try an Exchange... <<set_prices_exchange()>>
#
# <<set_prices_exchange()>>
# Buyer <Agents.Agent object at 0x000001CBB6AA09D0>
# Seller <Agents.Agent object at 0x000001CBB6AA29E0>
# Buyer Price:   10.000
# Seller Price:  10.000
#
# -Scenario 2-
# Enact Exchange
# -Buyer Price 10.000 higher than Seller Price 10.000-
#
#      <<_exchange()>>
#      -Exchanging-
#      Commodity 0
#
#      pmax_buyer:     10.000
#      pmin_seller:    10.000
#      Settled Price:  10.0
#
#       Before Exchange
#      Buyer <Agents.Agent object at 0x000001CBB6AA09D0>
#      Buyer Money:    166.667
#      Buyer D:        [2 0]
#      Buyer Q:        [0 0]
#      Buyer Exchange: [2 0]
#                      [ 2. -1.]
#
#      Seller <Agents.Agent object at 0x000001CBB6AA29E0>
#      Seller Money:   166.667
#      Seller D:       [0 2]
#      Seller Q:       [1 1]
#      Seller Exchange:[-1  1]
#                      [-1.  2.]
#
#      -Swap Items 0-
#      Market M 0:  10.000
#      Market Q 0:  1.0
#      Market p 0:  10.000
#
# <Agents.Agent object at 0x000001CBB6AA29E0> [1 1] [0 2] 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA3D00> [1 1] [0 2] 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA09D0> [0 0] [2 0] 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA29B0> [0 0] [2 0] 166.66666666666666
# None
# Buyer Q: [0 0]
# Buyer M: 166.66666666666666
# Seller Q: [1 1]
# Seller M: 166.66666666666666
# Buyer Q: [1 0]
# Buyer M: 156.66666666666666
# Seller Q: [0 1]
# Seller M: 176.66666666666666
# <Agents.Agent object at 0x000001CBB6AA29E0> [0 1] [0 2] 176.66666666666666
# <Agents.Agent object at 0x000001CBB6AA3D00> [0 1] [0 2] 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA09D0> [1 0] [2 0] 156.66666666666666
# <Agents.Agent object at 0x000001CBB6AA29B0> [1 0] [2 0] 166.66666666666666
# None
# {<Agents.Agent object at 0x000001CBB6AA29E0>: array([-1.,  2.]), <Agents.Agent object at 0x000001CBB6AA3D00>: array([-1.,  2.]), <Agents.Agent object at 0x000001CBB6AA09D0>: array([ 2., -1.]), <Agents.Agent object at 0x000001CBB6AA29B0>: array([ 2., -1.])}
# {<Agents.Agent object at 0x000001CBB6AA29E0>: array([0, 1]), <Agents.Agent object at 0x000001CBB6AA3D00>: array([-1.,  2.]), <Agents.Agent object at 0x000001CBB6AA09D0>: array([1, 0]), <Agents.Agent object at 0x000001CBB6AA29B0>: array([ 2., -1.])}
#       After Exchange
#      Buyer           <Agents.Agent object at 0x000001CBB6AA09D0>
#      Buyer Money:    156.667
#      Buyer D:        [2 0]
#      Buyer Q:        [1 0]
#      Buyer Exchange: [1 0]
#                      [1 0]
#
#      Seller          <Agents.Agent object at 0x000001CBB6AA29E0>
#      Seller Money:   176.667
#      Seller D:       [0 2]
#      Seller Q:       [0 1]
#      Seller Exchange:[0 1]
#                      [0 1]
#                 ------------
#
#      Dec. Buyer Price to 9.551 and inc. Seller Price to 10.313
#
# Return to <<attempt_exchange()>>
# ...After Trying Exchange, Set New Agent Prices
# New Buyer Price:     9.551
# New Seller Price:    10.313
#
# Agent <Agents.Agent object at 0x000001CBB6AA09D0> attempts increased from 0 to 1
# Agent <Agents.Agent object at 0x000001CBB6AA09D0> has had 1/1 attempts. Tap Out. Exit
#
# Agent <Agents.Agent object at 0x000001CBB6AA29E0> attempts increased from 0 to 1
# Agent <Agents.Agent object at 0x000001CBB6AA29E0> has had 1/1 attempts. Tap Out. Exit
#
# {<Agents.Agent object at 0x000001CBB6AA3D00>: array([-1.,  2.]), <Agents.Agent object at 0x000001CBB6AA29B0>: array([ 2., -1.])}
#             ------------
# Total Exchange Attempts 2/6
#
# {<Agents.Agent object at 0x000001CBB6AA3D00>: array([-1.,  2.]), <Agents.Agent object at 0x000001CBB6AA29B0>: array([ 2., -1.])}
# <<attempt_exchange>>
# Q of Agents
# <Agents.Agent object at 0x000001CBB6AA3D00> [0 1] [0 2] 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA29B0> [1 0] [2 0] 166.66666666666666
#
# M of Agents
# <Agents.Agent object at 0x000001CBB6AA3D00> 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA29B0> 166.66666666666666
#
# Buyer Set
# {<Agents.Agent object at 0x000001CBB6AA29B0>: 2.0}
#
# Seller Set
# {<Agents.Agent object at 0x000001CBB6AA3D00>: -1.0}
#
# <<attempt_exchange()>>
# --Attempt An Exchange--
# Commodity 0
#
# Buyer:     <Agents.Agent object at 0x000001CBB6AA29B0>
# Buyer D:   [2 0]
# Buyer Q:   [1 0]
# Buyer E:   2
#            [1 0]
#            [ 2. -1.]
#
# Seller:    <Agents.Agent object at 0x000001CBB6AA3D00>
# Seller D:  [0 2]
# Seller Q:  [0 1]
# Seller E:  -1
#            [0 1]
#            [-1.  2.]
#
# Set Prices and Try an Exchange... <<set_prices_exchange()>>
#
# <<set_prices_exchange()>>
# Buyer <Agents.Agent object at 0x000001CBB6AA29B0>
# Seller <Agents.Agent object at 0x000001CBB6AA3D00>
# Buyer Price:   10.000
# Seller Price:  10.000
#
# -Scenario 2-
# Enact Exchange
# -Buyer Price 10.000 higher than Seller Price 10.000-
#
#      <<_exchange()>>
#      -Exchanging-
#      Commodity 0
#
#      pmax_buyer:     10.000
#      pmin_seller:    10.000
#      Settled Price:  10.0
#
#       Before Exchange
#      Buyer <Agents.Agent object at 0x000001CBB6AA29B0>
#      Buyer Money:    166.667
#      Buyer D:        [2 0]
#      Buyer Q:        [1 0]
#      Buyer Exchange: [1 0]
#                      [ 2. -1.]
#
#      Seller <Agents.Agent object at 0x000001CBB6AA3D00>
#      Seller Money:   166.667
#      Seller D:       [0 2]
#      Seller Q:       [0 1]
#      Seller Exchange:[0 1]
#                      [-1.  2.]
#
#      -Swap Items 0-
#      Market M 0:  20.000
#      Market Q 0:  2.0
#      Market p 0:  10.000
#
# <Agents.Agent object at 0x000001CBB6AA3D00> [0 1] [0 2] 166.66666666666666
# <Agents.Agent object at 0x000001CBB6AA29B0> [1 0] [2 0] 166.66666666666666
# None
# Buyer Q: [1 0]
# Buyer M: 166.66666666666666
# Seller Q: [0 1]
# Seller M: 166.66666666666666
# Buyer Q: [2 0]
# Buyer M: 156.66666666666666
# Seller Q: [-1  1]
# Seller M: 176.66666666666666
# <Agents.Agent object at 0x000001CBB6AA3D00> [-1  1] [0 2] 176.66666666666666
# <Agents.Agent object at 0x000001CBB6AA29B0> [2 0] [2 0] 156.66666666666666
# None
# {<Agents.Agent object at 0x000001CBB6AA3D00>: array([-1.,  2.]), <Agents.Agent object at 0x000001CBB6AA29B0>: array([ 2., -1.])}
# {<Agents.Agent object at 0x000001CBB6AA3D00>: array([1, 1]), <Agents.Agent object at 0x000001CBB6AA29B0>: array([0, 0])}
#       After Exchange
#      Buyer           <Agents.Agent object at 0x000001CBB6AA29B0>
#      Buyer Money:    156.667
#      Buyer D:        [2 0]
#      Buyer Q:        [2 0]
#      Buyer Exchange: [0 0]
#                      [0 0]
#
#      Seller          <Agents.Agent object at 0x000001CBB6AA3D00>
#      Seller Money:   176.667
#      Seller D:       [0 2]
#      Seller Q:       [-1  1]
#      Seller Exchange:[1 1]
#                      [1 1]
#                 ------------
#
#      Dec. Buyer Price to 9.802 and inc. Seller Price to 10.129
#
# Return to <<attempt_exchange()>>
# ...After Trying Exchange, Set New Agent Prices
# New Buyer Price:     9.802
# New Seller Price:    10.129
#
# Agent <Agents.Agent object at 0x000001CBB6AA29B0> attempts increased from 0 to 1
# Agent <Agents.Agent object at 0x000001CBB6AA29B0> Satisified. Exit
#
# Agent <Agents.Agent object at 0x000001CBB6AA3D00> attempts increased from 0 to 1
# Agent <Agents.Agent object at 0x000001CBB6AA3D00> has had 1/1 attempts. Tap Out. Exit
#
# {}
#             ------------
# Total Exchange Attempts 3/6
#
# {}
# <<attempt_exchange>>
# Q of Agents
#
# M of Agents
#
# Buyer Set
# {}
#
# Seller Set
# {}
#
# <<attempt_exchange()>>
# --Attempt An Exchange--
# Commodity 0
#
# Commodity 0 cleared
#
# Total Exchange Attempts 4/6
#
# {}
# <<attempt_exchange>>
# Q of Agents
#
# M of Agents
#
# Buyer Set
# {}
#
# Seller Set
# {}
#
# <<attempt_exchange()>>
# --Attempt An Exchange--
# Commodity 1
#
# Commodity 1 cleared
#
# Total Exchange Attempts 5/6
#
#             ------------
# C:\Users\Alex\Documents\Research\EconoNet\v1\Markets.py:264: RuntimeWarning: invalid value encountered in scalar divide
#   _m = _P/_n # ERROR WHEN _n = 0!

# %%
#market.IntendedExchange
market.IntendedExchange#[buyer]
# Out:
# {}

# %%
agent_list[0], agent_list[1]
# Out:
# (<Agents.Agent at 0x1cbb6aa29e0>, <Agents.Agent at 0x1cbb6aa3d00>)

# %%
dict(zip(range(N),agent_list))
# Out:
# {0: <Agents.Agent at 0x1cbb6aa29e0>,
#  1: <Agents.Agent at 0x1cbb6aa3d00>,
#  2: <Agents.Agent at 0x1cbb6aa20b0>,
#  3: <Agents.Agent at 0x1cbb6aa09d0>,
#  4: <Agents.Agent at 0x1cbb6aa29b0>,
#  5: <Agents.Agent at 0x1cbb6aa2d10>}

# %%
plt.rcParams['figure.dpi'] = 100

# %%
plot_market(0, log=True)
plt.xlim(0,T)
#plt.ylim(1e-1, 2e2)

#name = f'method={price_adjust_method} M={M} gam={gamma} eps={epsilon} max_agent_tries={max_agent_tries}'
#plt.savefig('market_plot1 ' + name + '.png')
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_19144\3557236308.py:9: RuntimeWarning: invalid value encountered in divide
#   p = ME_df[:,i]/QE_df[:,i]
# (0.0, 2.0)

# %%
plot_market(1, log=True)
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_19144\3557236308.py:9: RuntimeWarning: invalid value encountered in divide
#   p = ME_df[:,i]/QE_df[:,i]

# %%
np.nanmean(ME_df/QE_df, axis=0)
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_19144\3985086816.py:1: RuntimeWarning: invalid value encountered in divide
#   np.nanmean(ME_df/QE_df, axis=0)
# array([10., 10.])

# %%
plot_prices(p_df, 0, log=True, includeM=True, A=0, B=NA)
plt.xlim(0,T)
#plt.ylim(1e-1, 2e2)

#name = f'method={price_adjust_method} M={M} gam={gamma} eps={epsilon} max_agent_tries={max_agent_tries}'
#plt.savefig('market_plot2 ' + name + '.png')
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_19144\3557236308.py:38: RuntimeWarning: invalid value encountered in divide
#   p = ME_df[:,i]/QE_df[:,i]
# (0.0, 2.0)

# %%
plot_quantities(Q_df, D_df, 0, A=0, B=NA)

# %%
plot_prices(p_df, 1, log=True, includeM=True, A=0, B=NA)
#plt.grid()
# Out:
# C:\Users\Alex\AppData\Local\Temp\ipykernel_19144\3557236308.py:38: RuntimeWarning: invalid value encountered in divide
#   p = ME_df[:,i]/QE_df[:,i]

# %%
plot_quantities(Q_df, D_df, 1, A=0, B=NA)

# %% [markdown]
# This scheme won't work when the price is zero.
#
# Because $p' = p_0 (1+\alpha)$ will equal zero when $p_0$ is zero

# %%
for i in range(n):
    y = Q_df.sum(axis=1)[:,i]
    
    plt.plot(y)

# %%
for v in range(len(agent_list)):
    y0 = Q_df[:,v,0]
    plt.plot(y0)

# %%
for v in range(len(agent_list)):
    y0 = Q_df[:,v,1]
    plt.plot(y0)

# %%
Q_df[:,1,1]
# Out:
# array([0., 1.])

# %%
agent_list[0].Q, agent_list[1].Q
# Out:
# (array([-1,  1]), array([-1,  1]))

# %%
plt.hist([agent.M for agent in agent_list])
plt.yscale('log')

# %%
Q = np.zeros(n)
for agent in agent_list:
    Q += agent.Q
    
Q
# Out:
# array([3., 3.])

# %%
Q = np.zeros(n)
for agent in agentA_list:
    Q += agent.Q
    
Q
# Out:
# array([-3.,  3.])
