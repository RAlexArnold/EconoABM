# %%
# Enable interactive plotting in the notebook
# %matplotlib notebook

# %%
import time
import seaborn as sns

import Agents
import Instruments
import Markets

import Simulate
import Environment

import numpy as np
from scipy.stats import norm, uniform
import random

import matplotlib.pyplot as plt

import SimPlotting

from matplotlib.animation import FuncAnimation

# %%
def initialize_agents(initial_parameters, learning_parameters) -> list:
    
    kwargs = {**initial_parameters, **learning_parameters}
    
    
    Agent_list = [Agents.Agent(**kwargs) for i in range(Nagents)]

    return Agent_list

# %%
def initialize_instruments(Nins_1, Nins_2, prod_vec):

    instruments = []

    #means = mean_productivities
    #stds = std_productivities

    for N in range(Nins_1):
        instrument = Instruments.IoP([prod_vec[0], 0])
        instruments.append(instrument)

    for N in range(Nins_2):
        instrument = Instruments.IoP([0, prod_vec[1]])
        instruments.append(instrument)
        
    return instruments

# %%
def initialize_allocation(agent_list, instrument_list):
    
    for agent in agent_list:
        
        random_instrument = random.choice(instrument_list)
        instrument_list.remove(random_instrument)
        
        agent.Ins = random_instrument

# %%
def initialize_market(market_parameters):
        
    market = Markets.SCDA(**market_parameters)
    
    return market

# %% [markdown]
# Initialize Parameters

# %%
dt = 1

Nagents = 100

Nactions = 4 # Null, Produce, Consume, Exchange (extra will be allocate when needed)

# %% [markdown]
# If we want the macroeconomic condition to be satisfied, then use the below
#
# Define l1 and l2
#
# Then we must define c1 and c2 so that $l_1 c_1 + l_2 c_2 \leq 1$

# %%
l1 = 1.0
l2 = 0.5

c1 = 0.1
c2 = 0.3

assert c1 <= 1/l1
c2_max = (1-l1*c1)/l2
assert c2 <= c2_max

condition = l1*c1 + l2*c2
print(condition)
L_nec = condition*Nagents
# Out:
# 0.25

# %%
cg = np.array([c1, c2])
Nproducts = cg.shape[0]

prod1 = 1./l1
prod2 = 1./l2

# %% [markdown]
# This then sets the size of each sector's workforce.
#
# So we can set the number of instruments available for each sector to match this ratio (scaling to 1 if condition is less than 1)

# %%
buffer = 1.0 # How many instruments per agent there are

K1 = int(round(l1*c1/condition*Nagents*buffer,0))
K2 = int(round(l2*c2/condition*Nagents*buffer,0))

K1, K2, K1+K2
# Out:
# (40, 60, 100)

# %%
initial_parameters = {
    'Q': np.zeros(Nproducts),
    'D': np.zeros(Nproducts),
    'cg': cg,
    'M': 100.,
    'n_actions': Nactions
}

learning_parameters = {
    'gamma': 0.9,
    'epsilon': 1.0,
    'eps_end': 0.01,
    'eps_dec': 0.01,
    'batch_size': 100,
    'input_dims': [3*Nproducts+1], # If needing to know, check the get_state() function in Simulate class
    'lr': 0.005,
    'n_actions':Nactions,
}

market_parameters = {
    'Nproducts': Nproducts,
    'theta': 0.1,
    'gamma': 1.0,
    'epsilon': 0.005,
    'max_tries': 100,
    'M_min': 0.01,
}

# %% [markdown]
# Initialize Agents, Instruments, and Markets

# %%
agent_list = initialize_agents(initial_parameters, learning_parameters)
instrument_list = initialize_instruments(K1, K2, [prod1, prod2])

initialize_allocation(agent_list, instrument_list)

market = initialize_market(market_parameters)

# %%
learn_trigger = -cg.sum()*10

# %%
env = Environment.Environment(dt, agent_list, instrument_list, market)
sim = Simulate.Simulate(env)

sim.set_reward_trigger_learn(learn_trigger)

# %% [markdown]
# Run Simulation

# %%
def action_probabilities():

    X = [(sim.Aarray == a).sum(axis=1) for a in sim.env.action_space]
    X = np.vstack(X)/float(Nagents)
    
    return X

# %%
from matplotlib.animation import FuncAnimation

Ntimes = 100

# Set up the figure for plotting
fig, ax = plt.subplots()
ax.set_xlim(0, Ntimes)
ax.set_ylim(0, 1)
line, = ax.plot([], [], lw=3)

def init():
    sim.reset()
    sim.initialize_arrays(Ntimes)
    t = 0
    tmax = sim.dt * Ntimes
    sim.trange = np.arange(t, tmax, sim.dt)
    sim.epsilon_list = []  # Same across all agents
    line.set_data([], [])
    return line,

def animate(i):
    sim.sim_step(i)  # Fix this line to use i instead of frame
    x = sim.trange[0:i]
    y = np.mean(sim.qarray[:i, 0], axis=1)
    line.set_data(x, y)
    return line

# Create the animation
ani = FuncAnimation(fig, animate, init_func=init, frames=Ntimes, repeat=False)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
from IPython.display import display

Ntimes = 10

# Set up the figure for plotting
fig, ax = plt.subplots()
ax.set_xlim(0, Ntimes)
ax.set_ylim(0, 1)
line_q1, = ax.plot([], [], lw=1, label='$q_1$', c='blue')


def init():
    
    sim.reset()
    sim.initialize_arrays(Ntimes)
    
    t = 0
    tmax = sim.dt * Ntimes
    sim.trange = np.arange(t, tmax, sim.dt)
    sim.epsilon_list = []  # Same across all agents
    
    line_q1.set_data([], [])
    #line_c1.set_data([], [])

    return line_q1, #line_c1,

def animate(i):
    
    print(f'Animate from {i}')
    sim.sim_step(i)
    print(sim.agent_list[0].Q[0])
    
    x = sim.trange[0:i]
    
    #q1, c1 = update_data(i)
    q1 = np.mean(sim.qarray[:i, 0], axis=1)
    #c1 = np.mean(sim.carray[:i, 0], axis=1)
    print(f"q1: {q1}, c1: {c1}")

    
    line_q1.set_data(x, q1)
    #line_c1.set_data(x, c1, c='red')
    
    return line_q1, #line_c1,

def update_data(i):
    q1 = np.mean(sim.qarray[:i, 0], axis=1)
    c1 = np.mean(sim.carray[:i, 0], axis=1)
    
    return q1, c1
  
# Set initial values
#init()

# Create the animation
ani = FuncAnimation(fig, animate, init_func=init, frames=Ntimes, repeat=False)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
from IPython.display import display

Ntimes = 50

# Set up the figure for plotting
fig, ax = plt.subplots()
ax.set_xlim(0, Ntimes)
ax.set_ylim(0, 1)
line_q1, = ax.plot([], [], lw=1, label='$q_1$')
#line_c1, = ax.plot([], [], lw=1, label='$c_1$')


def init():
    
    sim.reset()
    sim.initialize_arrays(Ntimes)
    
    t = 0
    tmax = sim.dt * Ntimes
    sim.trange = np.arange(t, tmax, sim.dt)
    sim.epsilon_list = []  # Same across all agents
    
    line_q1.set_data([], [])
    #line_c1.set_data([], [])

    return line_q1, #line_c1,

def animate(i):
    
    print(f'Animate from {i}')
    sim.sim_step(i)
    print(sim.agent_list[0].Q[0])
    
    x = sim.trange[0:i]
    
    #q1, c1 = update_data(i)
    q1 = np.mean(sim.qarray[:i, 0], axis=1)
    #c1 = np.mean(sim.carray[:i, 0], axis=1)
    print(f"q1: {q1}, c1: {c1}")

    
    line_q1.set_data(x, q1, c='blue')
    #line_c1.set_data(x, c1, c='red')
    
    return line_q1, #line_c1,

def update_data(i):
    q1 = np.mean(sim.qarray[:i, 0], axis=1)
    c1 = np.mean(sim.carray[:i, 0], axis=1)
    
    return q1, c1
  
# Set initial values
#init()

# Create the animation
ani = FuncAnimation(fig, animate, init_func=init, frames=Ntimes, repeat=False)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
assert False
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 assert False
#
# AssertionError:

# %%
from matplotlib.animation import FuncAnimation


Ntimes = 50

# Set up the figure for plotting
fig, ax = plt.subplots(1, 2, figsize=(10,4))

ax[0].set_xlim(0, Ntimes)
ax[0].set_ylim(0, 1)
line_q1, = ax[0].plot([], [], lw=1, label='$q_1$')
line_c1, = ax[0].plot([], [], lw=1, label='$c_1$')

ax[1].set_xlim(0, Ntimes)
ax[1].set_ylim(0, 1)
line_q2, = ax[1].plot([], [], lw=1, label='$q_2$')
line_c2, = ax[1].plot([], [], lw=1, label='$c_2$')
#line_actions = ax.plot([], [], lw=1, label='Actions')

lines = [line_q1, line_c1, line_q2, line_c2]

def init():
    
    sim.reset()
    sim.initialize_arrays(Ntimes)
    
    t = 0
    tmax = sim.dt * Ntimes
    sim.trange = np.arange(t, tmax, sim.dt)
    sim.epsilon_list = []  # Same across all agents
    
    line_q1.set_data([], [])
    line_q2.set_data([], [])
    line_c1.set_data([], [])
    line_c2.set_data([], [])

    return line_q1, line_c1, line_q2, line_c2

def animate(i):
    sim.sim_step(i) 
    x = sim.trange[0:i]
    
    q1, c1, q2, c2 = update_data(i)
    
    line_q1.set_data(x, q1, c='blue')
    line_c1.set_data(x, c1, c='red')
    line_q2.set_data(x, q2, c='blue')
    line_c2.set_data(x, c2, c='red')
    
    return lines

def update_data(i):
    q1 = np.mean(sim.qarray[:i, 0], axis=1)
    c1 = np.mean(sim.carray[:i, 0], axis=1)
    q2 = np.mean(sim.qarray[:i, 1], axis=1)
    c2 = np.mean(sim.carray[:i, 1], axis=1)
    
    return q1, c1, q2, c2


  
# Set initial values
#init()

# Create the animation
ani = FuncAnimation(fig, animate, init_func=init, frames=Ntimes, repeat=False)

plt.show()

# %%
sim.qarray[-1]

# %%
assert False

# %% [markdown]
# Plot

# %%
time_ratio = 300/1000

run_ratio = 126.76/646.4

time_ratio, run_ratio

# %%
splt = SimPlotting.SimPlotting(sim)
plt.rcParams['figure.dpi'] = 500

# %%
splt.plotA(lw1=0.5, lw2=0.1, ewm=False, alpha=0.01)
plt.axhline(condition, c='orange', lw=1.0, ls=':')
plt.show()

# %%
splt.plotQuantities(
    lw1=0.3, 
    lw2=0.05, 
    xmax=10, 
    tight_layout=True, 
    qlog=False,
    clog=False,
    Qlog=True, 
    Dlog=True, 
    qmin=0, 
    qmax=1, 
    cmin=0, 
    cmax=1,
    Qmin = 1e-1,
    Qmax=1e3,
    Dmin=1e-1,
    Dmax=1e3,
    med=False
)

# %%
splt.plotMarket(lw1=0.3, 
                lw2=0.05, 
                Mlog=True, 
                mNlog=True, 
                mMlog=True, 
                mElog=True, 
                plog=True)

# %%
splt.plotPolicy(0)

# %%
splt.plotPolicy('L')
plt.axhline(condition, c='k', lw=0.5)
plt.show()

# %%
splt.plotPolicy('C')

# %%
splt.plotPolicy('E')

# %%
N1 = 0
N2 = 0
for agent in agent_list:
    xi = agent.Ins.prod_vec
    
    if xi[0] != 0:
        N1 += 1
    elif xi[1] != 0:
        N2 += 1
    else:
        raise ValueError('Agent has Non-Productive Instrument')

# %%
N1, N2

# %%
# The instrument productivities
# ... or the output per instrument
q1_per_ins = 1./l1
q2_per_ins = 1./l2

q1_per_ins, q2_per_ins

# %%
# The total output actually recorded (at each time)
q1_tot = splt.qarray[:,0].sum(axis=1)
q2_tot = splt.qarray[:,1].sum(axis=1)

# %%
# The total workers actually recorded (at each time)
L1 = q1_tot/q1_per_ins
L2 = q2_tot/q2_per_ins

# %%
# The theoretically necessary workers needed to fulfil consumption requirements
L1_nec = cg[0]/q1_per_ins*Nagents
L2_nec = cg[1]/q2_per_ins*Nagents

L1_nec, L2_nec

# %%
# The total consumption actually recorded (at each time)
c1_tot = splt.carray[:,0].sum(axis=1)
c2_tot = splt.carray[:,1].sum(axis=1)

# %%
lw = 0.5
plt.plot(q1_tot, c='C0', lw=lw, label='Output 1')
plt.plot(c1_tot, c='red', lw=lw/2., label='Consumption 1')
plt.axhline(cg[0]*Nagents, c='r',lw=lw, label='Required Consumption 1')
#plt.yscale('log')
plt.legend()
plt.ylabel('$q_1, c_1$')

# %%
lw = 0.5
plt.plot(q2_tot, c='C0', lw=lw, label='Output 2')
plt.plot(c2_tot, c='red', lw=lw/2., label='Consumption 2')
plt.axhline(cg[1]*Nagents, c='r',lw=lw, label='Required Consumption 2')
#plt.yscale('log')
plt.legend()
plt.ylabel('$q_2, c_2$')

# %%
plt.plot(L1, c='C0', lw=lw, label='$L_1$')
plt.plot(L2, c='C1', lw=lw, label='$L_2$')

plt.axhline(L1_nec, c='blue', label='$L_1$ Required', lw=lw)
plt.axhline(L2_nec, c='orange', label='$L_2$ Required', lw=lw)
plt.legend()
plt.ylabel('L_1')

# %%
L1_nec

# %%
ME_df = splt.mMarray
QE_df = splt.mEarray
ntries_df = splt.narray
M_total = splt.Marray
p = splt.parray

def plot_market(i, *, ps=10, log=False, supply_demand=False, show_M_total=False, lw=0.5):

    f, ax = plt.subplots(1, figsize=(10,4)) #(2,1)

    ax.plot(ME_df[:,i], c='C0', label=f'$\Delta M_{i}$', lw=lw)
    ax.plot(QE_df[:,i], c='C1', label=f'$\Delta Q_{i}$', lw=lw)
    ax.plot(ntries_df, c='k', label='Tries', lw=lw)

    #ax.scatter(np.arange(0,T-1), p[:,i], c='g', label=f'$p_{i}$', s=ps)
    ax.plot(p[:,i], c='g', label=f'$p_{i}$', lw=lw)
    
    if supply_demand:
        ax.plot(supply_df[:,i], c='blue', ls='--', label=f'Supply', lw=lw)
        ax.plot(demand_df[:,i], c='orange', ls='--', label=f'Demand', lw=lw)
        
    if show_M_total:
        ax.plot(M_total, c='g', ls=':', label='$M_{total}$', lw=lw)

    ax.legend(bbox_to_anchor=(1, 0.5))
    
    if log:
        plt.yscale('log')
        
    plt.title(f'Market for Commodity {i}')
    plt.xlabel('t')
    plt.ylabel('$M$, $Q$')

# %%
plot_market(0, log=True)
plt.ylim(1e-1, 1e3)

# %%
plot_market(1, log=True)
plt.ylim(1e-1, 1e3)

# %%
l1, l2

# %%
p_mean = np.nanmean(sim.parray, axis=0)
p_mean

# %%
l1/l2, p_mean[0]/p_mean[1]

# %%
plt.scatter([l1, l2], p_mean)

# %%
plt.hist(np.log10(sim.parray[:,0]), histtype='step')
plt.hist(np.log10(sim.parray[:,1]), histtype='step')
plt.yscale('log')

# %%
sim.Darray[:,0]

# %%
sim.Darray[Ntimes-1, 1, Nagents-1 ]

# %%
plt.plot(sim.Darray[:, 0, 2])
plt.axhline(cg[0],c='k')
plt.yscale('log')

# %%
plt.plot(sim.Darray[:, 1, 2])
plt.axhline(cg[1], c='k')
plt.yscale('log')

# %%
cg

# %%
np.sum(cg)*10

# %%
plt.plot(sim.Darray[:,0,:].mean(axis=1))
plt.plot(sim.Darray[:,0,:].min(axis=1))
plt.plot(sim.Darray[:,0,:].max(axis=1))
plt.plot(np.median(sim.Darray[:,0,:], axis=1))
plt.yscale('log')

# %%
plt.plot(sim.Darray[:,1,:].mean(axis=1))
plt.plot(sim.Darray[:,1,:].min(axis=1))
plt.plot(sim.Darray[:,1,:].max(axis=1))
plt.plot(np.median(sim.Darray[:,1,:], axis=1))
plt.yscale('log')

# %%
sim.Darray[:,0].sum(axis=1)/Nagents

# %%
np.mean(sim.Darray[:,0], axis=1)

# %%
np.median(sim.Qarray[:,1], axis=1)

# %%
plt.plot(sim.Qarray[:,0,:].mean(axis=1))
plt.plot(sim.Qarray[:,0,:].min(axis=1))
plt.plot(sim.Qarray[:,0,:].max(axis=1))
plt.plot(np.median(sim.Qarray[:,0,:], axis=1))
#plt.yscale('log')

# %%
splt.plotQi
