# %%
import time
import seaborn as sns

import Agents
import Instruments
import Markets

import Simulate
import Environment

import numpy as np
from scipy.stats import norm, uniform
import random

import matplotlib.pyplot as plt

import SimPlotting

import cProfile
import pstats

# %%
def initialize_agents(initial_parameters, learning_parameters) -> list:
    
    kwargs = {**initial_parameters, **learning_parameters}
    
    
    Agent_list = [Agents.Agent(**kwargs) for i in range(Nagents)]

    return Agent_list

# %%
def initialize_instruments(Nins_1, Nins_2, prod_vec):

    instruments = []

    #means = mean_productivities
    #stds = std_productivities

    for N in range(Nins_1):
        instrument = Instruments.IoP([prod_vec[0], 0])
        instruments.append(instrument)

    for N in range(Nins_2):
        instrument = Instruments.IoP([0, prod_vec[1]])
        instruments.append(instrument)
        
    return instruments

# %%
def initialize_allocation(agent_list, instrument_list):
    
    for agent in agent_list:
        
        random_instrument = random.choice(instrument_list)
        instrument_list.remove(random_instrument)
        
        agent.Ins = random_instrument

# %%
def initialize_market(market_parameters):
        
    market = Markets.SCDA(**market_parameters)
    
    return market

# %% [markdown]
# Initialize Parameters

# %%
dt = 1

Nagents = 100

Nactions = 4 # Null, Produce, Consume, Exchange (extra will be allocate when needed)

# %% [markdown]
# If we want the macroeconomic condition to be satisfied, then use the below
#
# Define l1 and l2
#
# Then we must define c1 and c2 so that $l_1 c_1 + l_2 c_2 \leq 1$

# %%
l1 = 1.0
l2 = 0.5

c1 = 0.1
c2 = 0.3

assert c1 <= 1/l1
c2_max = (1-l1*c1)/l2
assert c2 <= c2_max

condition = l1*c1 + l2*c2
print(condition)
L_nec = condition*Nagents
# Out:
# 0.25

# %%
cg = np.array([c1, c2])
Nproducts = cg.shape[0]

prod1 = 1./l1
prod2 = 1./l2

# %% [markdown]
# This then sets the size of each sector's workforce.
#
# So we can set the number of instruments available for each sector to match this ratio (scaling to 1 if condition is less than 1)

# %%
buffer = 1.0 # How many instruments per agent there are

K1 = int(round(l1*c1/condition*Nagents*buffer,0))
K2 = int(round(l2*c2/condition*Nagents*buffer,0))

K1, K2, K1+K2
# Out:
# (40, 60, 100)

# %%
initial_parameters = {
    'Q': np.zeros(Nproducts),
    'D': np.zeros(Nproducts),
    'cg': cg,
    'M': 100.,
    'n_actions': Nactions
}

learning_parameters = {
    'gamma': 0.9,
    'epsilon': 1.0,
    'eps_end': 0.05,
    'eps_dec': 0.01,
    'batch_size': 100,
    'input_dims': [3*Nproducts+1], # If needing to know, check the get_state() function in Simulate class
    'lr': 0.005,
    'n_actions':Nactions,
}

market_parameters = {
    'Nproducts': Nproducts,
    'theta': 0.05,
    'gamma': 1.0,
    'epsilon': 0.05,
    'max_tries': 100,
    'M_min': 0.01,
}

# %% [markdown]
# Initialize Agents, Instruments, and Markets

# %%
agent_list = initialize_agents(initial_parameters, learning_parameters)
instrument_list = initialize_instruments(K1, K2, [prod1, prod2])

initialize_allocation(agent_list, instrument_list)

market = initialize_market(market_parameters)

# %%
for agent in agent_list:
    agent.action_space = [1,2,3]
    
agent_list[-1].action_space
# Out:
# [1, 2, 3]

# %%
learn_trigger = -cg.sum()*10

# %%
env = Environment.Environment(dt, agent_list, instrument_list, market)
sim = Simulate.Simulate(env)

sim.set_reward_trigger_learn(learn_trigger)

# %% [markdown]
# Run Simulation

# %%
print((3.48 * 10))
print((3.48 * 10)/60.)
print((3.48 * 10)/60./60.)
# Out:
# 34.8
# 0.58
# 0.009666666666666665

# %%
# 10 minutes per 1000 times

# %%
Ntimes = 1000

def main():
    sim.run_simulation(Ntimes)
    
e = time.perf_counter()

# %%
if __name__ == "__main__":
    profiler = cProfile.Profile()
    profiler.enable()

    main()  # Call your main function

    profiler.disable()
    stats = pstats.Stats(profiler)
    stats.strip_dirs()
    stats.sort_stats('cumulative')
    stats.print_stats()
# Out:
#          42251311 function calls (42251309 primitive calls) in 1004.041 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000 1004.041 1004.041 2438922261.py:3(main)
#         1    0.008    0.008 1004.041 1004.041 Simulate.py:145(run_simulation)
#      1000   10.983    0.011 1004.029    1.004 Simulate.py:169(sim_step)
#    100000   33.923    0.000  893.151    0.009 Agents.py:139(learn)
#     91200    1.161    0.000  358.807    0.004 _tensor.py:428(backward)
#     91200    1.212    0.000  357.610    0.004 __init__.py:106(backward)
#     91200  353.114    0.004  353.114    0.004 {method 'run_backward' of 'torch._C._EngineBase' objects}
#     91200    3.992    0.000  268.641    0.003 optimizer.py:265(wrapper)
#     91200    1.710    0.000  252.485    0.003 optimizer.py:29(_use_grad)
#     91200    1.781    0.000  249.537    0.003 adam.py:108(step)
#     91200    0.897    0.000  241.223    0.003 adam.py:231(adam)
#     91200   52.489    0.001  238.086    0.003 adam.py:300(_single_tensor_adam)
#    264488    9.791    0.000  208.950    0.001 Agents.py:32(forward)
#    884664    5.863    0.000  180.663    0.000 module.py:1494(_call_impl)
#    793464    5.346    0.000  160.803    0.000 linear.py:113(forward)
#    793464  153.769    0.000  153.769    0.000 {built-in method torch._C._nn.linear}
#      1000    0.009    0.000   44.003    0.044 Environment.py:43(env_step)
#    100000    1.277    0.000   43.762    0.000 Agents.py:126(choose_action)
#   1094400   43.364    0.000   43.364    0.000 {method 'mul_' of 'torch._C._TensorBase' objects}
#      1000    0.011    0.000   42.728    0.043 Environment.py:61(perform_actions)
#      1000    0.010    0.000   41.821    0.042 Environment.py:152(perform_exchange)
#      1000    0.390    0.000   41.778    0.042 Markets.py:266(run_exchange)
#     40638    6.217    0.000   40.686    0.001 Markets.py:136(attempt_trial)
#    547200   40.482    0.000   40.482    0.000 {method 'sqrt' of 'torch._C._TensorBase' objects}
#    547200   37.505    0.000   37.505    0.000 {method 'addcdiv_' of 'torch._C._TensorBase' objects}
#   1094400   33.794    0.000   33.794    0.000 {method 'add_' of 'torch._C._TensorBase' objects}
#    186838   15.672    0.000   27.669    0.000 {method 'choice' of 'numpy.random.mtrand.RandomState' objects}
#    528976    1.622    0.000   26.987    0.000 functional.py:1446(relu)
#    528976   24.990    0.000   24.990    0.000 {built-in method torch.relu}
#    547200   21.083    0.000   21.083    0.000 {method 'addcmul_' of 'torch._C._TensorBase' objects}
#    830920    4.171    0.000   14.531    0.000 fromnumeric.py:71(_wrapreduction)
#    447488   14.236    0.000   14.236    0.000 {built-in method torch.tensor}
#     91200    4.128    0.000   12.149    0.000 optimizer.py:435(zero_grad)
#     91200   10.754    0.000   10.754    0.000 {built-in method torch.max}
#    182400    1.495    0.000   10.716    0.000 profiler.py:491(__enter__)
#     91200    0.380    0.000   10.353    0.000 loss.py:535(forward)
#     91200    1.083    0.000    9.973    0.000 functional.py:3267(mse_loss)
#    182400    0.523    0.000    9.220    0.000 _ops.py:497(__call__)
#    182400    8.697    0.000    8.697    0.000 {built-in method torch._ops.profiler._record_function_enter_new}
#    912196    8.268    0.000    8.268    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#     38863    3.333    0.000    7.045    0.000 Markets.py:103(update_prices)
#    182400    2.458    0.000    6.329    0.000 profiler.py:495(__exit__)
#    186838    0.795    0.000    6.309    0.000 fromnumeric.py:2979(prod)
#     91200    4.791    0.000    6.285    0.000 adam.py:66(_init_group)
#     91200    5.983    0.000    5.983    0.000 {built-in method torch._C._nn.mse_loss}
#   2471592    5.005    0.000    5.005    0.000 module.py:1601(__getattr__)
#    177726    0.960    0.000    4.866    0.000 fromnumeric.py:2177(sum)
#     77726    1.350    0.000    4.796    0.000 _logsumexp.py:131(softmax)
#    547200    2.203    0.000    4.752    0.000 optimizer.py:39(_get_value)
#    200000    4.435    0.000    4.697    0.000 Simulate.py:92(get_state)
#    100000    0.292    0.000    4.595    0.000 Simulate.py:75(update_reward)
#    100000    0.507    0.000    4.303    0.000 Simulate.py:69(reward_function_deficit)
#     80478    2.447    0.000    3.739    0.000 {method 'uniform' of 'numpy.random.mtrand.RandomState' objects}
#    182400    0.379    0.000    3.709    0.000 _ops.py:286(__call__)
#    884664    3.644    0.000    3.644    0.000 {built-in method torch._C._get_tracing_state}
#    182400    3.330    0.000    3.330    0.000 {built-in method torch._ops.profiler.}
#     91037    0.369    0.000    3.087    0.000 arraysetops.py:138(unique)
#    547200    1.695    0.000    2.826    0.000 optimizer.py:52(_dispatch_sqrt)
#     91200    1.139    0.000    2.658    0.000 __init__.py:50(_make_grads)
#     91037    1.989    0.000    2.547    0.000 arraysetops.py:323(_unique1d)
#    629288    2.438    0.000    2.438    0.000 {method 'item' of 'torch._C._TensorBase' objects}
#     91200    1.071    0.000    2.391    0.000 functional.py:45(broadcast_tensors)
#    182400    1.654    0.000    2.389    0.000 profiler.py:482(__init__)
#    194315    0.460    0.000    2.333    0.000 fromnumeric.py:2836(min)
#    538088    1.996    0.000    1.996    0.000 {method 'to' of 'torch._C._TensorBase' objects}
#     82088    1.724    0.000    1.724    0.000 {built-in method torch.argmax}
#    116589    0.316    0.000    1.623    0.000 fromnumeric.py:2692(max)
#    100000    1.548    0.000    1.548    0.000 Simulate.py:125(update_arrays)
#     91200    0.885    0.000    1.424    0.000 optimizer.py:64(_default_to_fused_or_foreach)
#     91200    1.266    0.000    1.266    0.000 {built-in method torch.ones_like}
#     77726    0.215    0.000    1.255    0.000 fromnumeric.py:2814(amax)
#     77726    0.237    0.000    1.254    0.000 fromnumeric.py:2421(all)
#    100000    1.253    0.000    1.253    0.000 Agents.py:117(store_transition)
#    830920    1.231    0.000    1.231    0.000 fromnumeric.py:72(<dictcomp>)
#    182400    0.367    0.000    1.212    0.000 {built-in method builtins.all}
#     91037    0.213    0.000    1.186    0.000 fromnumeric.py:2512(cumsum)
#    182400    0.903    0.000    1.127    0.000 grad_mode.py:149(__init__)
#     77726    0.358    0.000    1.118    0.000 {method 'prod' of 'numpy.generic' objects}
#   1701214    1.059    0.000    1.059    0.000 {built-in method builtins.isinstance}
#     77726    0.748    0.000    0.993    0.000 _util.py:194(_asarray_validated)
#     91037    0.205    0.000    0.973    0.000 fromnumeric.py:53(_wrapfunc)
#    547200    0.965    0.000    0.965    0.000 {built-in method torch.is_complex}
#    551475    0.958    0.000    0.958    0.000 {built-in method builtins.getattr}
#     91200    0.941    0.000    0.941    0.000 {built-in method torch.broadcast_tensors}
#    547200    0.827    0.000    0.827    0.000 {method 'conj' of 'torch._C._TensorBase' objects}
#     81276    0.129    0.000    0.808    0.000 {method 'sum' of 'numpy.ndarray' objects}
#      1000    0.805    0.001    0.805    0.001 Environment.py:67(update_consumption_deficit)
#     77726    0.076    0.000    0.760    0.000 _methods.py:51(_prod)
#   2828203    0.746    0.000    0.746    0.000 {method 'append' of 'list' objects}
#     91037    0.717    0.000    0.717    0.000 {method 'cumsum' of 'numpy.ndarray' objects}
#     77726    0.284    0.000    0.708    0.000 numerictypes.py:357(issubdtype)
#     81276    0.074    0.000    0.679    0.000 _methods.py:47(_sum)
# 182401/182400    0.659    0.000    0.659    0.000 typing.py:306(inner)
#    547800    0.368    0.000    0.609    0.000 _tensor.py:942(__hash__)
#    638400    0.456    0.000    0.563    0.000 adam.py:268(<genexpr>)
#    100000    0.561    0.000    0.561    0.000 {method 'random' of 'numpy.random.mtrand.RandomState' objects}
#      1000    0.499    0.000    0.533    0.001 Environment.py:115(perform_consume)
#    568953    0.503    0.000    0.503    0.000 {built-in method math.sqrt}
#   1368000    0.456    0.000    0.456    0.000 _jit_internal.py:1102(is_scripting)
#      1000    0.432    0.000    0.432    0.000 Environment.py:50(reset_flows)
#    620176    0.411    0.000    0.411    0.000 {built-in method torch._C._has_torch_function_unary}
#     91201    0.408    0.000    0.408    0.000 {method 'format' of 'str' objects}
#    155452    0.266    0.000    0.407    0.000 numerictypes.py:283(issubclass_)
#    182400    0.372    0.000    0.372    0.000 optimizer.py:72(<genexpr>)
#      1000    0.246    0.000    0.363    0.000 Environment.py:84(perform_produce)
#     21753    0.305    0.000    0.353    0.000 Markets.py:59(enact_transaction)
#    834920    0.340    0.000    0.340    0.000 {method 'items' of 'dict' objects}
#     91201    0.330    0.000    0.330    0.000 {built-in method numpy.arange}
#     91200    0.217    0.000    0.327    0.000 _VF.py:26(__getattr__)
#    155452    0.253    0.000    0.324    0.000 getlimits.py:484(__new__)
#    182400    0.322    0.000    0.322    0.000 {method 'size' of 'torch._C._TensorBase' objects}
#     40638    0.112    0.000    0.307    0.000 random.py:375(choice)
#    813717    0.303    0.000    0.303    0.000 {built-in method builtins.len}
#     38863    0.302    0.000    0.302    0.000 Markets.py:190(<listcomp>)
#      1000    0.041    0.000    0.292    0.000 Markets.py:277(<listcomp>)
#     91200    0.263    0.000    0.263    0.000 {built-in method torch._C._are_functorch_transforms_active}
#     26322    0.256    0.000    0.256    0.000 {built-in method numpy.array}
#     25643    0.251    0.000    0.251    0.000 Markets.py:50(determine_market_quantity)
#    151816    0.247    0.000    0.247    0.000 {built-in method builtins.min}
#     38863    0.246    0.000    0.246    0.000 Markets.py:193(<listcomp>)
#    547800    0.241    0.000    0.241    0.000 {built-in method builtins.id}
#    273600    0.232    0.000    0.232    0.000 {built-in method torch.is_grad_enabled}
#    547200    0.219    0.000    0.219    0.000 _utils.py:786(is_compiling)
#     91037    0.206    0.000    0.206    0.000 {method 'flatten' of 'numpy.ndarray' objects}
#     91037    0.185    0.000    0.185    0.000 {method 'argsort' of 'numpy.ndarray' objects}
#     40638    0.139    0.000    0.184    0.000 random.py:239(_randbelow_with_getrandbits)
#     77726    0.103    0.000    0.170    0.000 numeric.py:415(count_nonzero)
#    364800    0.167    0.000    0.167    0.000 {method 'values' of 'collections.OrderedDict' objects}
#    233178    0.158    0.000    0.158    0.000 {built-in method builtins.issubclass}
#    223322    0.157    0.000    0.157    0.000 Instruments.py:38(prod_vec)
#     91037    0.145    0.000    0.145    0.000 {built-in method numpy.empty}
#     91200    0.144    0.000    0.144    0.000 optimizer.py:228(_cuda_graph_capture_health_check)
#    246652    0.138    0.000    0.138    0.000 {method 'get' of 'dict' objects}
#     91200    0.135    0.000    0.135    0.000 __init__.py:98(_tensor_or_tensors_to_tuple)
#     91200    0.133    0.000    0.133    0.000 {method 'numel' of 'torch._C._TensorBase' objects}
#     91200    0.131    0.000    0.131    0.000 _reduction.py:7(get_enum)
#     91037    0.088    0.000    0.128    0.000 arraysetops.py:125(_unpack_tuple)
#     77726    0.070    0.000    0.126    0.000 _base.py:1461(issparse)
#    200000    0.114    0.000    0.114    0.000 multiarray.py:153(concatenate)
#     77726    0.104    0.000    0.104    0.000 {built-in method builtins.max}
#    182400    0.103    0.000    0.103    0.000 {built-in method torch._C._set_grad_enabled}
#    177726    0.103    0.000    0.103    0.000 fromnumeric.py:2172(_sum_dispatcher)
#    186838    0.100    0.000    0.100    0.000 fromnumeric.py:2974(_prod_dispatcher)
#    182400    0.097    0.000    0.097    0.000 {method '__exit__' of 'torch._C.DisableTorchFunctionSubclass' objects}
#     77726    0.059    0.000    0.082    0.000 core.py:6480(isMaskedArray)
#    182400    0.075    0.000    0.075    0.000 __init__.py:89(annotate)
#      1000    0.038    0.000    0.074    0.000 Markets.py:255(randomize_prices)
#    194315    0.070    0.000    0.070    0.000 fromnumeric.py:2687(_max_dispatcher)
#    194315    0.067    0.000    0.067    0.000 fromnumeric.py:2831(_min_dispatcher)
#     77726    0.067    0.000    0.067    0.000 {built-in method numpy.core._multiarray_umath.count_nonzero}
#    182074    0.065    0.000    0.065    0.000 {built-in method numpy.asanyarray}
#     91200    0.064    0.000    0.064    0.000 {built-in method torch._C._has_torch_function_variadic}
#      1000    0.064    0.000    0.064    0.000 Markets.py:124(record_updated_prices)
#     91200    0.064    0.000    0.064    0.000 {built-in method builtins.hasattr}
#     23322    0.018    0.000    0.062    0.000 function_base.py:873(copy)
#     91200    0.052    0.000    0.052    0.000 {built-in method torch._C._has_torch_function}
#     91200    0.047    0.000    0.047    0.000 optimizer.py:249(_optimizer_step_code)
#     91037    0.042    0.000    0.042    0.000 arraysetops.py:133(_unique_dispatcher)
#      2000    0.034    0.000    0.041    0.000 Markets.py:38(reset)
#     77726    0.038    0.000    0.038    0.000 fromnumeric.py:2416(_all_dispatcher)
#     91037    0.037    0.000    0.037    0.000 fromnumeric.py:2508(_cumsum_dispatcher)
#     77726    0.037    0.000    0.037    0.000 {built-in method numpy.asarray}
#      1000    0.036    0.000    0.036    0.000 Environment.py:86(<dictcomp>)
#      1000    0.036    0.000    0.036    0.000 Simulate.py:117(update_market_arrays)
#     77726    0.034    0.000    0.034    0.000 numeric.py:411(_count_nonzero_dispatcher)
#      1000    0.034    0.000    0.034    0.000 Environment.py:120(<dictcomp>)
#      1000    0.031    0.000    0.031    0.000 Environment.py:155(<dictcomp>)
#     81541    0.030    0.000    0.030    0.000 {method 'getrandbits' of '_random.Random' objects}
#      1000    0.003    0.000    0.029    0.000 Environment.py:58(reset_market)
#      1200    0.023    0.000    0.023    0.000 {built-in method torch.zeros_like}
#     40638    0.015    0.000    0.015    0.000 {method 'bit_length' of 'int' objects}
#      6111    0.011    0.000    0.011    0.000 {built-in method numpy.zeros}
#     51286    0.009    0.000    0.009    0.000 {method 'random' of '_random.Random' objects}
#      1000    0.008    0.000    0.008    0.000 Markets.py:274(<dictcomp>)
#      1000    0.007    0.000    0.007    0.000 Markets.py:278(<listcomp>)
#     23322    0.007    0.000    0.007    0.000 function_base.py:869(_copy_dispatcher)
#      1000    0.004    0.000    0.004    0.000 Markets.py:273(<listcomp>)
#         1    0.000    0.000    0.003    0.003 Simulate.py:31(reset)
#         1    0.000    0.000    0.003    0.003 Environment.py:29(reset)
#         1    0.000    0.000    0.002    0.002 Environment.py:36(initialize_bids_asks)
#      4000    0.002    0.000    0.002    0.000 {method 'keys' of 'dict' objects}
#      1775    0.002    0.000    0.002    0.000 {method 'remove' of 'list' objects}
#         1    0.000    0.000    0.002    0.002 Simulate.py:101(initialize_arrays)
#       100    0.000    0.000    0.001    0.000 Agents.py:98(reset)
#       2/1    0.000    0.000    0.000    0.000 typing.py:401(__getitem__)
#         1    0.000    0.000    0.000    0.000 typing.py:523(Optional)
#         1    0.000    0.000    0.000    0.000 _ops.py:447(__getattr__)
#         1    0.000    0.000    0.000    0.000 typing.py:483(Union)
#         3    0.000    0.000    0.000    0.000 typing.py:146(_type_check)
#         3    0.000    0.000    0.000    0.000 typing.py:137(_type_convert)
#         1    0.000    0.000    0.000    0.000 typing.py:1016(__init__)
#         1    0.000    0.000    0.000    0.000 typing.py:664(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#         1    0.000    0.000    0.000    0.000 _ops.py:239(__init__)
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._get_operation_overload}
#         8    0.000    0.000    0.000    0.000 typing.py:986(__setattr__)
#         1    0.000    0.000    0.000    0.000 typing.py:947(__init__)
#         3    0.000    0.000    0.000    0.000 typing.py:515(<genexpr>)
#         8    0.000    0.000    0.000    0.000 typing.py:935(_is_dunder)
#         1    0.000    0.000    0.000    0.000 typing.py:267(_remove_dups_flatten)
#        13    0.000    0.000    0.000    0.000 typing.py:705(__eq__)
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._get_schema}
#         1    0.000    0.000    0.000    0.000 typing_extensions.py:181(_collect_type_vars)
#         1    0.000    0.000    0.000    0.000 typing.py:253(_deduplicate)
#         2    0.000    0.000    0.000    0.000 typing.py:714(__hash__)
#         2    0.000    0.000    0.000    0.000 typing_extensions.py:169(_should_collect_from_parameters)
#         9    0.000    0.000    0.000    0.000 {method 'startswith' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 typing.py:1022(<genexpr>)
#         4    0.000    0.000    0.000    0.000 {method 'endswith' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.setattr}
#         1    0.000    0.000    0.000    0.000 typing.py:380(__repr__)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# Plot

# %%
time_ratio = 300/1000

run_ratio = 126.76/646.4

time_ratio, run_ratio

# %%
splt = SimPlotting.SimPlotting(sim)
plt.rcParams['figure.dpi'] = 500

# %%
action_dict = {0:'L', 1: 'C',2: 'E'}
[plt.plot(a, label=action_dict[i], lw=0.5) for i,a in enumerate(splt.action_probabilities())]
plt.plot(sim.epsilon_list, c='k', lw=0.5)
plt.axhline(condition, c='blue', lw=0.5)
plt.ylim(0,1)
plt.legend()

# %%
#splt.plotA(lw1=0.5, lw2=0.1, ewm=False, alpha=0.01)
#plt.axhline(condition, c='orange', lw=1.0, ls=':')
#plt.show()

# %%
splt.plotQuantities(
    lw1=0.3, 
    lw2=0.01, 
    xmax=10, 
    tight_layout=True, 
    qlog=False,
    clog=False,
    Qlog=True, 
    Dlog=True, 
    qmin=0, 
    qmax=0.6, 
    cmin=0, 
    cmax=0.6,
    Qmin = 1e-1,
    Qmax=1e3,
    Dmin=1e-1,
    Dmax=1e3,
    med=False
)

# %%
splt.plotMarket(lw1=0.3, 
                lw2=0.05, 
                Mlog=False, 
                mNlog=True, 
                mMlog=False, 
                mElog=False, 
                plog=True)

# %%
splt.plotPolicy(0)
plt.axhline(condition, c='k', lw=0.5)
plt.title('Action L Probabilities')

# %%
splt.plotPolicy(1)
#plt.axhline(condition, c='k', lw=0.5)
plt.title('Action C Probabilities')
plt.show()

# %%
splt.plotPolicy(2)
plt.title('Action E Probabilities')

# %%
##splt.plotPolicy(3)

# %%
N1 = 0
N2 = 0
for agent in agent_list:
    xi = agent.Ins.prod_vec
    
    if xi[0] != 0:
        N1 += 1
    elif xi[1] != 0:
        N2 += 1
    else:
        raise ValueError('Agent has Non-Productive Instrument')

# %%
N1, N2

# %%
# The instrument productivities
# ... or the output per instrument
q1_per_ins = 1./l1
q2_per_ins = 1./l2

q1_per_ins, q2_per_ins

# %%
# The total output actually recorded (at each time)
q1_tot = splt.qarray[:,0].sum(axis=1)
q2_tot = splt.qarray[:,1].sum(axis=1)

print(np.nanmean(q1_tot)/Nagents, np.nanmean(q2_tot)/Nagents)
print(np.nanmedian(q1_tot)/Nagents, np.nanmedian(q2_tot)/Nagents)

# %%
# The total workers actually recorded (at each time)
L1 = q1_tot/q1_per_ins
L2 = q2_tot/q2_per_ins

print(np.nanmean(L1), np.nanmean(L2))
print(np.nanmedian(L1), np.nanmedian(L2))

# %%
# The theoretically necessary workers needed to fulfil consumption requirements
L1_nec = cg[0]/q1_per_ins*Nagents
L2_nec = cg[1]/q2_per_ins*Nagents

print(L1_nec, L2_nec)

# %%
# The total consumption actually recorded (at each time)
c1_tot = splt.carray[:,0].sum(axis=1)
c2_tot = splt.carray[:,1].sum(axis=1)

print( round(np.nanmean(c1_tot)/Nagents,2), round(np.nanmean(c2_tot)/Nagents,2) )
print( round(np.nanmedian(c1_tot)/Nagents,2), round(np.nanmedian(c2_tot)/Nagents,2) )

# %%
# the required consumption
print(cg[0], cg[1])

# %%
lw = 0.1
plt.plot(q1_tot, c='C0', lw=lw, label='Output 1')
plt.plot(c1_tot, c='red', lw=lw, label='Consumption 1')
plt.axhline(cg[0]*Nagents, c='r',lw=2*lw, label='Required Consumption 1')
#plt.yscale('log')
plt.legend()
plt.ylabel('$q_1, c_1$')
plt.yscale('log')

# %%
lw = 0.1
plt.plot(q2_tot, c='C0', lw=lw, label='Output 2')
plt.plot(c2_tot, c='red', lw=lw, label='Consumption 2')
plt.axhline(cg[1]*Nagents, c='r',lw=2*lw, label='Required Consumption 2')
#plt.yscale('log')
plt.legend()
plt.ylabel('$q_2, c_2$')
plt.yscale('log')

# %%
lw = 0.1
plt.plot(L1, c='C0', lw=lw, label='$L_1$')
plt.plot(L2, c='C1', lw=lw, label='$L_2$')

plt.axhline(L1_nec, c='blue', label='$L_1$ Required', lw=10*lw)
plt.axhline(L2_nec, c='orange', label='$L_2$ Required', lw=10*lw)
plt.legend()
plt.ylabel('$L_i$')

# %%
ME_df = splt.mMarray
QE_df = splt.mEarray
ntries_df = splt.narray
M_total = splt.Marray
p = splt.parray

def plot_market(i, *, ps=10, log=False, supply_demand=False, show_M_total=False, lw=0.5):

    f, ax = plt.subplots(1, figsize=(10,4)) #(2,1)

    ax.plot(ME_df[:,i], c='C0', label=f'$\Delta M_{i}$', lw=lw)
    ax.plot(QE_df[:,i], c='C1', label=f'$\Delta Q_{i}$', lw=lw)
    ax.plot(ntries_df, c='k', label='Tries', lw=lw)

    #ax.scatter(np.arange(0,T-1), p[:,i], c='g', label=f'$p_{i}$', s=ps)
    ax.plot(p[:,i], c='g', label=f'$p_{i}$', lw=lw)
    
    if supply_demand:
        ax.plot(supply_df[:,i], c='blue', ls='--', label=f'Supply', lw=lw)
        ax.plot(demand_df[:,i], c='orange', ls='--', label=f'Demand', lw=lw)
        
    if show_M_total:
        ax.plot(M_total, c='g', ls=':', label='$M_{total}$', lw=lw)

    ax.legend(bbox_to_anchor=(1, 0.5))
    
    if log:
        plt.yscale('log')
        
    plt.title(f'Market for Commodity {i}')
    plt.xlabel('t')
    plt.ylabel('$M$, $Q$')

# %%
plot_market(0, log=True)
plt.ylim(1e-1, 1e3)

# %%
plot_market(1, log=True)
plt.ylim(1e-1, 1e3)

# %%
lw = 0.5
plt.plot(sim.parray[:,0], lw=lw)
plt.plot(sim.parray[:,1], lw=lw)
plt.yscale('log')
plt.ylabel('$p_i$')

# %%
lw = 0.5
plt.plot(sim.parray[:,0]/sim.parray[:,1], lw=lw)
plt.axhline(l1/l2, c='k', lw=lw)
plt.yscale('log')

# %%
print(l1, l2)
print(l1/l2)

# %%
start_t = 0#6000

# %%
p_mean = np.nanmean(sim.parray[start_t:], axis=0)
print(p_mean)
print(p_mean[0]/p_mean[1])

# %%
l1/l2, p_mean[0]/p_mean[1]

# %%
p_ratio = sim.parray[start_t:,0]/sim.parray[start_t:,1]
np.nanmean(p_ratio), np.nanmedian(p_ratio)

# %%
plt.hist(np.log10(p_ratio), histtype='step')
plt.axvline(np.log10(l1/l2))

# %%
np.nanmean(p_ratio), np.nanmedian(p_ratio)

# %%
plt.scatter([l1, l2], p_mean)

# %%
plt.hist(np.log10(sim.parray[:,0]), histtype='step')
plt.hist(np.log10(sim.parray[:,1]), histtype='step')
plt.yscale('log')

# %%
sim.Darray[:,0]

# %%
sim.Darray[Ntimes-1, 1, Nagents-1 ]

# %%
plt.plot(sim.Darray[:, 0, 2])
plt.axhline(cg[0],c='k')
plt.yscale('log')

# %%
plt.plot(sim.Darray[:, 1, 2])
plt.axhline(cg[1], c='k')
plt.yscale('log')

# %%
plt.plot(sim.Darray[:,0,:].mean(axis=1))
plt.plot(sim.Darray[:,0,:].min(axis=1))
plt.plot(sim.Darray[:,0,:].max(axis=1))
plt.plot(np.median(sim.Darray[:,0,:], axis=1))
plt.yscale('log')

# %%
plt.plot(sim.Darray[:,1,:].mean(axis=1))
plt.plot(sim.Darray[:,1,:].min(axis=1))
plt.plot(sim.Darray[:,1,:].max(axis=1))
plt.plot(np.median(sim.Darray[:,1,:], axis=1))
plt.yscale('log')

# %%
sim.Darray[:,0].sum(axis=1)/Nagents

# %%
np.mean(sim.Darray[:,0], axis=1)

# %%
plt.hist(np.mean(sim.Darray[:,0], axis=0))
plt.xlabel(r'$\langle D^\nu \rangle$')

# %%
plt.hist(np.log10(np.mean(sim.Darray[:,0], axis=0)))
plt.xlabel(r'$\langle D^\nu \rangle$')

# %%
plt.hist(np.median(sim.Darray[:,0], axis=0))
plt.xlabel(r'$\langle D^\nu \rangle$')

# %%
np.median(sim.Darray[:,0],axis=0)

# %%
np.mean(sim.Darray[:,0], axis=0).mean(), np.mean(sim.Darray[:,1], axis=0).mean()

# %%
np.log10(np.mean(sim.Darray[:,0], axis=0)).mean(), np.log10(np.mean(sim.Darray[:,1], axis=0)).mean()

# %%
np.log10(np.mean(sim.Darray[:,0], axis=0)).std(), np.log10(np.mean(sim.Darray[:,1], axis=0)).std()

# %%
np.mean(sim.Darray[:,0], axis=1).mean()

# %%
sim.Darray[:,0].mean(), sim.Darray[:,0].std()

# %%
np.mean(sim.Darray[:,0], axis=0).std() #<- this to use

# %%
np.mean(sim.Darray[:,0], axis=0).std(), np.mean(sim.Darray[:,1], axis=0).std()

# %%
np.mean(sim.Darray[:,0], axis=1).std()

# %%
np.mean(sim.Darray[:,0], axis=1).mean()

# %%
np.median(sim.Qarray[:,1], axis=1)

# %%
plt.plot(sim.Qarray[:,0,:].mean(axis=1))
plt.plot(sim.Qarray[:,0,:].min(axis=1))
plt.plot(sim.Qarray[:,0,:].max(axis=1))
plt.plot(np.median(sim.Qarray[:,0,:], axis=1))
plt.yscale('log')

# %%
splt.plotQi

# %%
i = 1
f'{i:03d}'

# %%
import torch as T

save = False

def save_model(agent, i):
    
    path = f'agent_weights/agent_{i:03d}_weights.pth'
    T.save(agent.QNN.state_dict(), path)

if save:
    for i,agent in enumerate(agent_list):
        save_model(agent, i)
